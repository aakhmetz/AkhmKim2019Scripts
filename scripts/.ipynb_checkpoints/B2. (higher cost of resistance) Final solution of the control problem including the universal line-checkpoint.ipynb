# %% [markdown]
# # Aim of this notebook
#
# * To construct the singular curve of universal type to finalize the solution of the optimal control problem

# %% [markdown]
# # Preamble

# %%
from sympy import *
init_printing(use_latex='mathjax')

# Plotting
# %matplotlib inline
## Make inline plots raster graphics
from IPython.display import set_matplotlib_formats
## Import modules for plotting and data analysis
import matplotlib.pyplot as plt
from matplotlib import gridspec,rc,colors
import matplotlib.ticker as plticker
## Parameters for seaborn plots
import seaborn as sns
sns.set(style='white',font_scale=1.25,
        rc={"xtick.major.size": 6, "ytick.major.size": 6,
            'text.usetex': False, 'font.family': 'serif', 'font.serif': ['Times']})

import pandas as pd
pd.set_option('mode.chained_assignment',None)

import numpy as np
from scipy.optimize import fsolve, root
from scipy.integrate import ode
backend = 'dopri5'
import warnings

# Timer
import time

from copy import deepcopy

from itertools import cycle
palette_size = 10;
clrs = sns.color_palette("Reds",palette_size)
iclrs = cycle(clrs) # iterated colors

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter values

# %% [markdown]
# * Birth rate and const of downregulation are defined below in order to fit some experim. data

# %%
d = .13 # death rate
c = .06 # cost of resistance
α = .3 # low equilibrium point at expression of the main pathway (high equilibrium is at one)
θ = .45 # threshold value for the expression of the main pathway
κ = 40 # robustness parameter
L = .2 # parameter used to model the effect of treatment (see the line below)

# %% [markdown]
# * Symbolic variables - the list insludes μ & μbar, because they will be varied later

# %%
σ, φ0, φ, x, μ, μbar = symbols('sigma, phi0, phi, x, mu, mubar')

# %% [markdown]
# * Main functions

# %%
A = 1-σ*(1-θ)*(1-L)
Θ = θ+σ*(1-θ)*L
Eminus = (α*A-Θ)**2/2
ΔE = A*(1-α)*((1+α)*A/2-Θ)
ΔEf = lambdify(σ,ΔE)

# %% [markdown]
# * Birth rate and cost of downregulation

# %%
b = (0.1*(exp(κ*(ΔEf(1)))+1)-0.14*(exp(κ*ΔEf(0))+1))/(exp(κ*ΔEf(1))-exp(κ*ΔEf(0))) # birth rate
χ = 1-(0.14*(exp(κ*ΔEf(0))+1)-b*exp(κ*ΔEf(0)))/b
b, χ
# Out:
# (0.140154784911281, 0.299759386875464)

# %% [markdown]
# * Hamiltonian *H* and a part of it ρ that includes the control variable σ

# %%
h = b*(χ/(exp(κ*ΔE)+1)*(1-x)+c*x)
H = -φ0 + φ*(b*(χ/(exp(κ*ΔE)+1)-c)*x*(1-x)+μ*(1-x)/(exp(κ*ΔE)+1)-μbar*exp(-κ*Eminus)*x) + h
ρ = (φ*(b*χ*x+μ)+b*χ)/(exp(κ*ΔE)+1)*(1-x)-φ*μbar*exp(-κ*Eminus)*x
H, ρ
# Out:
# ⎛  ⎛                                                                       2
# ⎜  ⎜                μ⋅(-x + 1)                        -20⋅(-0.242⋅σ - 0.15)
# ⎜φ⋅⎜───────────────────────────────────────── - μ̅⋅x⋅ℯ                       +
# ⎜  ⎜ 40⋅(-0.396⋅σ + 0.2)⋅(-0.308⋅σ + 0.7)
# ⎝  ⎝ℯ                                     + 1
#
#
#    ⎛                                   0.042012712392668            ⎞
#  x⋅⎜-0.00840928709467684 + ─────────────────────────────────────────⎟⋅(-x + 1)
#    ⎜                        40⋅(-0.396⋅σ + 0.2)⋅(-0.308⋅σ + 0.7)    ⎟
#    ⎝                       ℯ                                     + 1⎠
#
# ⎞
# ⎟                                        0.042012712392668⋅(-x + 1)
# ⎟ - φ₀ + 0.00840928709467684⋅x + ─────────────────────────────────────────, -
# ⎟                                 40⋅(-0.396⋅σ + 0.2)⋅(-0.308⋅σ + 0.7)
# ⎠                                ℯ                                     + 1
#
#                              2
#         -20⋅(-0.242⋅σ - 0.15)    (-x + 1)⋅(φ⋅(μ + 0.042012712392668⋅x) + 0.042
# μ̅⋅φ⋅x⋅ℯ                       + ─────────────────────────────────────────────
#                                           40⋅(-0.396⋅σ + 0.2)⋅(-0.308⋅σ + 0.7)
#                                          ℯ
#
#              ⎞
# 012712392668)⎟
# ─────────────⎟
#              ⎟
#  + 1         ⎠

# %% [markdown]
# * Same but for no treatment (σ = 0)

# %%
h0 = h.subs(σ,0)
H0 = H.subs(σ,0)
ρ0 = ρ.subs(σ,0)
H0, ρ0
# Out:
# (φ⋅(0.00368423989943599⋅μ⋅(-x + 1) - 0.637628151621773⋅μ̅⋅x - 0.00825450218339
# 624⋅x⋅(-x + 1)) - φ₀ + 0.00825450218339624⋅x + 0.000154784911280596, -0.637628
# 151621773⋅μ̅⋅φ⋅x + 0.00368423989943599⋅(-x + 1)⋅(φ⋅(μ + 0.042012712392668⋅x) +
#  0.042012712392668))

# %% [markdown]
# * Machinery: definition of the Poisson brackets

# %%
PoissonBrackets = lambda H1, H2: diff(H1,x)*diff(H2,φ)-diff(H1,φ)*diff(H2,x)

# %% [markdown]
# * Necessary functions and defining the right hand side of dynamical equations

# %%
ρf = lambdify((x,φ,σ,μ,μbar),ρ)
ρ0f = lambdify((x,φ,μ,μbar),ρ0)
dxdτ = lambdify((x,φ,σ,μ,μbar),-diff(H,φ))
dφdτ = lambdify((x,φ,σ,μ,μbar),diff(H,x))
dVdτ = lambdify((x,σ),h)
dρdσ = lambdify((σ,x,φ,μ,μbar),diff(ρ,σ))
dδρdτ = lambdify((x,φ,σ,μ,μbar),-PoissonBrackets(ρ0-ρ,H))
def ode_rhs(t,state,μ,μbar):
    x, φ, V, δρ = state
    σs = [0,1]
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σstar = 1.;
    if ρf(x,φ,σstar,μ,μbar) < ρ0f(x,φ,μ,μbar):
        sgm = 0
    else:
        sgm = σstar
    return [dxdτ(x,φ,sgm,μ,μbar),dφdτ(x,φ,sgm,μ,μbar),dVdτ(x,sgm),dδρdτ(x,φ,σstar,μ,μbar)]

# %%
def get_primary_field(name, experiment,μ,μbar):
    solutions = {}
    solver = ode(ode_rhs).set_integrator(backend)
    τ0 = experiment['τ0']
    tms = np.linspace(τ0,experiment['T_end'],1e3+1)
    for x0 in experiment['x0']:
        δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
        solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
        sol = []; k = 0;
        while (solver.t < experiment['T_end']) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
            solver.integrate(tms[k])
            sol.append([solver.t]+list(solver.y))
            k += 1
        solutions[x0] = {'solution': sol}
    for x0, entry in solutions.items():
        entry['τ'] = [entry['solution'][j][0] for j in range(len(entry['solution']))]
        entry['x'] = [entry['solution'][j][1] for j in range(len(entry['solution']))]
        entry['φ'] = [entry['solution'][j][2] for j in range(len(entry['solution']))]
        entry['V'] = [entry['solution'][j][3] for j in range(len(entry['solution']))]
        entry['δρ'] = [entry['solution'][j][4] for j in range(len(entry['solution']))]
    return solutions
def get_δρ_value(tme,x0,μ,μbar):
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    while (solver.t < tme) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tme)
        sol = [solver.t]+list(solver.y)
    return solver.y[3]
def get_δρ_ending(params,μ,μbar):
    tme, x0 = params
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    _k = 0; sol = []
    while (_k<len(tms)):# and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append(solver.y)
        _k += 1
    #print(sol)
    return(sol[0][3],(sol[1][3]-sol[0][3])/δτ)
def get_state(tme,x0,μ,μbar):
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    _k = 0; sol = []
    while (solver.t < tms[-1]) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append(solver.y)
        _k += 1
    return(list(sol[0])+[(sol[1][3]-sol[0][3])/δτ])

# %% [markdown]
# # Machinery for the universal line

# %% [markdown]
# * To find the universal singular curve we need to define two parameters

# %%
γ0 = PoissonBrackets(PoissonBrackets(H,H0),H)
γ1 = PoissonBrackets(PoissonBrackets(H0,H),H0)

# %% [markdown]
# * The dynamics

# %%
dxdτSingExpr = -(γ0*diff(H0,φ)+γ1*diff(H,φ))/(γ0+γ1)
dφdτSingExpr = (γ0*diff(H0,x)+γ1*diff(H,x))/(γ0+γ1)
dVdτSingExpr = (γ0*h0+γ1*h)/(γ0+γ1)
σSingExpr = γ1*σ/(γ0+γ1)

# %% [markdown]
# * Machinery for Python: lambdify the functions above

# %%
dxdτSing = lambdify((x,φ,σ,μ,μbar),dxdτSingExpr)
dφdτSing = lambdify((x,φ,σ,μ,μbar),dφdτSingExpr)
dVdτSing = lambdify((x,φ,σ,μ,μbar),dVdτSingExpr)
σSing = lambdify((x,φ,σ,μ,μbar),σSingExpr)

# %%
def ode_rhs_Sing(t,state,μ,μbar):
    x, φ, V = state
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σstar = 1.;
    #print([σstar,σSing(x,φ,σstar,μ,μbar)])
    return [dxdτSing(x,φ,σstar,μ,μbar),dφdτSing(x,φ,σstar,μ,μbar),dVdτSing(x,φ,σstar,μ,μbar)]
# def ode_rhs_Sing(t,state,μ,μbar):
#     x, φ, V = state
#     if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
#         σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
#     else:
#         σstar = 1.;
#     σTrav = fsolve(lambda σ: dxdτ(x,φ,σ,μ,μbar)-dxdτSing(x,φ,σstar,μ,μbar),.6)[0]
#     print([σstar,σTrav])
#     return [dxdτSing(x,φ,σstar,μ,μbar),dφdτSing(x,φ,σstar,μ,μbar),dVdτ(x,σTrav)]
def get_universal_curve(end_point,tmax,Nsteps,μ,μbar):
    tms =  np.linspace(end_point[0],tmax,Nsteps);
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    _k = 0; sol = []
    while (solver.t < tms[-1]):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_σ_universal(tme,end_point,μ,μbar):
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    _k = 0; sol = []
    while (solver.t < tme+δτ):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    x, φ = sol[0][:2]
    sgm = fsolve(lambda σ: dxdτ(x,φ,σ,μ,μbar)-(sol[1][0]-sol[0][0])/δτ,θ/2)[0]
    return sgm
def get_state_universal(tme,end_point,μ,μbar):
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    solver.integrate(tme)
    return [solver.t]+list(solver.y)

# %%
def ode_rhs_with_σstar(t,state,μ,μbar):
    x, φ, V = state
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σ = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σ = 1.;
    return [dxdτ(x,φ,σ,μ,μbar),dφdτ(x,φ,σ,μ,μbar),dVdτ(x,σ)]
def ode_rhs_with_given_σ(t,state,σ,μ,μbar):
    x, φ, V = state
    return [dxdτ(x,φ,σ,μ,μbar),dφdτ(x,φ,σ,μ,μbar),dVdτ(x,σ)]
def get_trajectory_with_σstar(starting_point,tmax,Nsteps,μ,μbar):
    tms = np.linspace(starting_point[0],tmax,Nsteps)
    solver = ode(ode_rhs_with_σstar).set_integrator(backend)
    solver.set_initial_value(starting_point[1:],starting_point[0]).set_f_params(μ,μbar)
    sol = []; _k = 0;
    while solver.t < max(tms) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_trajectory_with_given_σ(starting_point,tmax,Nsteps,σ,μ,μbar):
    tms = np.linspace(starting_point[0],tmax,100)
    solver = ode(ode_rhs_with_given_σ).set_integrator(backend)
    solver.set_initial_value(starting_point[1:],starting_point[0]).set_f_params(σ,μ,μbar)
    sol = []; _k = 0;
    while solver.t < max(tms) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_state_with_σstar(tme,starting_point,μ,μbar):
    solver = ode(ode_rhs_with_σstar).set_integrator(backend)
    solver.set_initial_value(starting_point[1:4],starting_point[0]).set_f_params(μ,μbar)
    solver.integrate(tme)
    return [solver.t]+list(solver.y)
def get_finalizing_point_from_universal_curve(tme,tmx,end_point,μ,μbar):
    unv_point = get_state_universal(tme,end_point,μ,μbar)
    return get_state_with_σstar(tmx,unv_point,μ,μbar)[1]

# %% [markdown]
# # Field of optimal trajectories as the solution of the Bellman equation
#
# * μ & μbar are varied by *T* and *T*bar ($\mu=1/T$ and $\bar\mu=1/\bar{T}$)

# %%
tmx = 720.
end_switching_curve = {'t': 24., 'x': .9/.8} 
# for Τ, Τbar in zip([28]*5,[14,21,28,35,60]):
for Τ, Τbar in zip([28]*2,[60,120]):
    μ = 1./Τ; μbar = 1./Τbar
    print("Parameters: μ = %.5f, μbar = %.5f"%(μ,μbar))
    end_switching_curve['t'], end_switching_curve['x'] = fsolve(get_δρ_ending,(end_switching_curve['t'],.8*end_switching_curve['x']),args=(μ,μbar),xtol=1.0e-12)
    end_point = [end_switching_curve['t']]+get_state(end_switching_curve['t'],end_switching_curve['x'],μ,μbar)
    print("Ending point for the switching line: τ = %.1f days, x = %.1f%%" % (end_point[0], end_point[1]*100))
    print("Checking the solution - should give zero values: ")
    print(get_δρ_ending([end_switching_curve['t'],end_switching_curve['x']],μ,μbar))
    print("* Constructing the primary field")
    experiments = {
        'sol1': { 'T_end': tmx, 'τ0': 0., 'x0': list(np.linspace(0,end_switching_curve['x']-(1e-3),10))+list(np.linspace(end_switching_curve['x']+(1e-6),1.,10)) } }
    primary_field = []
    for name, values in experiments.items():
        primary_field.append(get_primary_field(name,values,μ,μbar))
    print("* Constructing the switching curve")
    switching_curve = []
    x0s = np.linspace(end_switching_curve['x'],1,21); _y = end_switching_curve['t']
    
    for x0 in x0s:
        tme = fsolve(get_δρ_value,_y,args=(x0,μ,μbar))[0]
        if (tme>0):
            switching_curve = switching_curve+[[tme,get_state(tme,x0,μ,μbar)[0]]]
            _y = tme
    print("* Constructing the universal curve")
    universal_curve = get_universal_curve(end_point,tmx,25,μ,μbar)
    print("* Finding the last characteristic")
    #time0 = time.time()
    tuniv = fsolve(get_finalizing_point_from_universal_curve,tmx-40.,args=(tmx,end_point,μ,μbar,))[0]
    #print("The proccess to find the last characteristic took %0.1f minutes" % ((time.time()-time0)/60.))
    univ_point = get_state_universal(tuniv,end_point,μ,μbar)
    print("The last point on the universal line:")
    print(univ_point)
    last_trajectory = get_trajectory_with_σstar(univ_point,tmx,50,μ,μbar)
    print("Final state:")
    final_state = get_state_with_σstar(tmx,univ_point,μ,μbar)
    print(final_state)
    print("Fold-change in tumor size: %.2f"%(exp((b-d)*tmx-final_state[-1])))
    # Plotting
    plt.rcParams['figure.figsize'] = (6.75, 4)
    _k = 0
    for solutions in primary_field:
        for x0, entry in solutions.items():
            plt.plot(entry['τ'], entry['x'], 'k-', linewidth=.9, color=clrs[_k%palette_size])
            _k += 1
    plt.plot([x[0] for x in switching_curve],[x[1] for x in switching_curve],linewidth=2,color="red")
    plt.plot([end_point[0]],[end_point[1]],marker='o',color="red")
    plt.plot([x[0] for x in universal_curve],[x[1] for x in universal_curve],linewidth=2,color="red")
    plt.plot([x[0] for x in last_trajectory],[x[1] for x in last_trajectory],linewidth=.9,color="black")
    plt.xlim([0,tmx]); plt.ylim([0,1]);
    plt.xlabel("time, days"); plt.ylabel("fraction of resistant cells")
    plt.show()
    print()
# Out:
# Parameters: μ = 0.03571, μbar = 0.01667
# Ending point for the switching line: τ = 22.4 days, x = 78.9%
# Checking the solution - should give zero values:
# (-1.6043001476664316e-05, -1.7958862004387351e-05)
# * Constructing the primary field
# * Constructing the switching curve
# * Constructing the universal curve
# * Finding the last characteristic
# The last point on the universal line:
# [701.4634641191067, 0.54987504798284226, -0.15259853504750065, 7.1597848901526051]
# Final state:
# [720.0, -8.3266726846886741e-16, -0.61330348944916446, 7.7315920400822531]
# Fold-change in tumor size: 0.66
# Parameters: μ = 0.03571, μbar = 0.00833
# Ending point for the switching line: τ = 21.8 days, x = 88.5%
# Checking the solution - should give zero values:
# (-1.5405443126625878e-07, 1.0745115861733232e-07)
# * Constructing the primary field
# * Constructing the switching curve
# * Constructing the universal curve
# * Finding the last characteristic
# The last point on the universal line:
# [675.602482406807, 0.88776053043527003, -0.37694943095288908, 6.4595504059732995]
# Final state:
# [720.0, -1.4051260155412137e-14, -0.89815384702801071, 7.4420072794775143]
# Fold-change in tumor size: 0.88

# %%
import csv
from numpy.linalg import norm
File = open("../results/sensitivity_mu.csv", 'w')
File.write("T,Tbar,mu,mubar,sw_end_t,sw_end_x,univ_point_t,univ_point_x,outcome,err_sw_t,err_sw_x\n")
writer = csv.writer(File,lineterminator='\n')

tmx = 720.
end_switching_curve0 = {'t': 24., 'x': .9/.8} 
end_switching_curve_prev_t = end_switching_curve['t']
tuniv = tmx-30.
Τbars = np.arange(120,2,-2)
for Τ in np.arange(74,2,-2): #Tbars
    μ = 1./Τ
    end_switching_curve = deepcopy(end_switching_curve0)
    for Τbar in reversed(Τbars):
        μbar = 1./Τbar
        print("* Parameters: T = %.1f, Tbar = %.1f (μ = %.5f, μbar = %.5f)"%(Τ,Τbar,μ,μbar))
        success = False; err = 1.
        while (not success)|(norm(err)>1e-6):
            end_switching_curve = {'t': 2*end_switching_curve['t']-end_switching_curve_prev_t-.001, 
                                   'x': end_switching_curve['x']-0.002} 
            sol = root(get_δρ_ending,(end_switching_curve['t'],end_switching_curve['x']),args=(μ,μbar))
            end_switching_curve_prev_t = end_switching_curve['t']
            end_switching_curve_prev_x = end_switching_curve['x']
            end_switching_curve['t'], end_switching_curve['x'] = sol.x   
            success = sol.success
            err = get_δρ_ending([end_switching_curve['t'],end_switching_curve['x']],μ,μbar)
            if (not success): 
                print("! Trying again...", sol.message)
            elif (norm(err)>1e-6):
                print("! Trying again... Convergence is not sufficient")       
        else:
            end_point = [end_switching_curve['t']]+get_state(end_switching_curve['t'],end_switching_curve['x'],μ,μbar)
            print("Ending point: t = %.2f, x = %.2f%%"%(end_switching_curve['t'],100*end_switching_curve['x'])," Checking the solution:",err)
            universal_curve = get_universal_curve(end_point,tmx,25,μ,μbar)
            tuniv = root(get_finalizing_point_from_universal_curve,tuniv,args=(tmx,end_point,μ,μbar)).x
            err_tuniv = get_finalizing_point_from_universal_curve(tuniv,tmx,end_point,μ,μbar)
            univ_point = get_state_universal(tuniv,end_point,μ,μbar)
            print("tuniv = %.2f"%tuniv," Checking the solution: ",err_tuniv)
            final_state = get_state_with_σstar(tmx,univ_point,μ,μbar)
            outcome = exp((b-d)*tmx-final_state[-1])
            print("Fold-change in tumor size: %.2f"%(outcome))
            output = [Τ,Τbar,μ,μbar,end_switching_curve['t'],end_switching_curve['x']]+list(univ_point[0:2])+[outcome]+list(err)+[err_tuniv]
            writer.writerow(output)
        if (Τbar==Τ):
            end_switching_curve0 = deepcopy(end_switching_curve) 

File.close()
# Out:
# * Parameters: T = 74.0, Tbar = 4.0 (μ = 0.01351, μbar = 0.25000)
# Ending point: t = 21.17, x = 46.37%  Checking the solution: (-7.7927000518684258e-12, -7.9985376397680075e-13)
# tuniv = 697.23  Checking the solution:  -3.1918911958e-16
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 6.0 (μ = 0.01351, μbar = 0.16667)
# Ending point: t = 22.88, x = 54.45%  Checking the solution: (-3.2702941374883332e-12, -3.0510314555948342e-13)
# tuniv = 694.77  Checking the solution:  6.97801538774e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 8.0 (μ = 0.01351, μbar = 0.12500)
# Ending point: t = 24.24, x = 60.13%  Checking the solution: (-1.7738455686732921e-08, 1.8274067475076587e-09)
# tuniv = 692.66  Checking the solution:  2.01274691358e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 10.0 (μ = 0.01351, μbar = 0.10000)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.36, x = 64.42%  Checking the solution: (-1.7426252904876802e-12, -8.3563467104364846e-12)
# tuniv = 690.83  Checking the solution:  -3.32210821352e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 12.0 (μ = 0.01351, μbar = 0.08333)
# Ending point: t = 26.30, x = 67.79%  Checking the solution: (-9.1389642147753037e-12, 2.3911342278813049e-12)
# tuniv = 689.21  Checking the solution:  9.30403323829e-13
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 14.0 (μ = 0.01351, μbar = 0.07143)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 27.12, x = 70.54%  Checking the solution: (-5.9568355251406061e-08, -5.7587657398360971e-07)
# tuniv = 688.28  Checking the solution:  -8.14848188924e-13
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 16.0 (μ = 0.01351, μbar = 0.06250)
# Ending point: t = 27.80, x = 72.83%  Checking the solution: (5.9140793119954321e-12, 3.8688868184316769e-12)
# tuniv = 686.40  Checking the solution:  -9.88295556503e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 74.0, Tbar = 18.0 (μ = 0.01351, μbar = 0.05556)
# Ending point: t = 28.42, x = 74.76%  Checking the solution: (-7.9234557081620004e-08, -1.5539144201575853e-07)
# tuniv = 685.32  Checking the solution:  -5.89622795033e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 74.0, Tbar = 20.0 (μ = 0.01351, μbar = 0.05000)
# Ending point: t = 28.95, x = 76.42%  Checking the solution: (-5.3586267528780702e-12, -4.1994263332826628e-13)
# tuniv = 684.00  Checking the solution:  3.08921777048e-11
# Fold-change in tumor size: 0.01
# * Parameters: T = 74.0, Tbar = 22.0 (μ = 0.01351, μbar = 0.04545)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 29.50, x = 77.87%  Checking the solution: (-1.4888890636611618e-07, -9.1621996157968108e-07)
# tuniv = 684.03  Checking the solution:  1.63759214522e-11
# Fold-change in tumor size: 0.01
# * Parameters: T = 74.0, Tbar = 24.0 (μ = 0.01351, μbar = 0.04167)
# Ending point: t = 29.88, x = 79.15%  Checking the solution: (-3.7130248420162715e-12, -2.896243667883715e-13)
# tuniv = 681.89  Checking the solution:  5.2822884955e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 74.0, Tbar = 26.0 (μ = 0.01351, μbar = 0.03846)
# Ending point: t = 30.28, x = 80.27%  Checking the solution: (-1.7187123602905347e-07, -6.7577267913793344e-09)
# tuniv = 680.94  Checking the solution:  4.8297199573e-12
# Fold-change in tumor size: 0.02
# * Parameters: T = 74.0, Tbar = 28.0 (μ = 0.01351, μbar = 0.03571)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 30.68, x = 81.28%  Checking the solution: (-4.3620654299788471e-08, -5.0826114723554256e-07)
# tuniv = 680.75  Checking the solution:  -1.42451987706e-11
# Fold-change in tumor size: 0.02
# * Parameters: T = 74.0, Tbar = 30.0 (μ = 0.01351, μbar = 0.03333)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 30.99, x = 82.19%  Checking the solution: (-2.010413333567603e-07, -1.3805002531354691e-07)
# tuniv = 679.35  Checking the solution:  -1.50894990947e-11
# Fold-change in tumor size: 0.03
# * Parameters: T = 74.0, Tbar = 32.0 (μ = 0.01351, μbar = 0.03125)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 31.37, x = 83.01%  Checking the solution: (-1.8933953622077494e-07, -8.9630136507913149e-07)
# tuniv = 679.71  Checking the solution:  -3.02521896423e-11
# Fold-change in tumor size: 0.03
# * Parameters: T = 74.0, Tbar = 34.0 (μ = 0.01351, μbar = 0.02941)
# Ending point: t = 31.58, x = 83.76%  Checking the solution: (-2.4231072478047366e-07, -1.003307984923877e-07)
# tuniv = 677.67  Checking the solution:  5.4934320981e-12
# Fold-change in tumor size: 0.04
# * Parameters: T = 74.0, Tbar = 36.0 (μ = 0.01351, μbar = 0.02778)
# Ending point: t = 31.84, x = 84.44%  Checking the solution: (-1.1115690407406495e-07, -4.8861110120743096e-08)
# tuniv = 676.82  Checking the solution:  6.02031619001e-12
# Fold-change in tumor size: 0.04
# * Parameters: T = 74.0, Tbar = 38.0 (μ = 0.01351, μbar = 0.02632)
# Ending point: t = 32.08, x = 85.06%  Checking the solution: (5.9208120889019545e-13, 4.2768448648420142e-13)
# tuniv = 676.00  Checking the solution:  -1.11577756756e-09
# Fold-change in tumor size: 0.05
# * Parameters: T = 74.0, Tbar = 40.0 (μ = 0.01351, μbar = 0.02500)
# Ending point: t = 32.31, x = 85.64%  Checking the solution: (-8.3252130775139654e-14, 9.0595866068554979e-15)
# tuniv = 675.28  Checking the solution:  -4.10296796538e-14
# Fold-change in tumor size: 0.06
# * Parameters: T = 74.0, Tbar = 42.0 (μ = 0.01351, μbar = 0.02381)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 32.53, x = 86.17%  Checking the solution: (-3.9420984515982707e-14, -1.1081255353384388e-15)
# tuniv = 674.60  Checking the solution:  2.92592339246e-13
# Fold-change in tumor size: 0.06
# * Parameters: T = 74.0, Tbar = 44.0 (μ = 0.01351, μbar = 0.02273)
# Ending point: t = 32.73, x = 86.67%  Checking the solution: (-6.786582641617623e-14, -3.028853533701421e-15)
# tuniv = 673.93  Checking the solution:  9.55015233561e-12
# Fold-change in tumor size: 0.07
# * Parameters: T = 74.0, Tbar = 46.0 (μ = 0.01351, μbar = 0.02174)
# Ending point: t = 32.92, x = 87.12%  Checking the solution: (-5.2141023127534516e-14, -4.0729191459148444e-15)
# tuniv = 673.29  Checking the solution:  1.19315732641e-10
# Fold-change in tumor size: 0.08
# * Parameters: T = 74.0, Tbar = 48.0 (μ = 0.01351, μbar = 0.02083)
# Ending point: t = 33.09, x = 87.55%  Checking the solution: (-2.4376570204509814e-08, 9.0085658386150099e-08)
# tuniv = 672.46  Checking the solution:  1.59309440639e-11
# Fold-change in tumor size: 0.08
# * Parameters: T = 74.0, Tbar = 50.0 (μ = 0.01351, μbar = 0.02000)
# Ending point: t = 33.29, x = 87.95%  Checking the solution: (-7.6191592223001964e-08, -1.1512303777610198e-07)
# tuniv = 672.33  Checking the solution:  -2.56975829505e-11
# Fold-change in tumor size: 0.09
# * Parameters: T = 74.0, Tbar = 52.0 (μ = 0.01351, μbar = 0.01923)
# Ending point: t = 33.48, x = 88.32%  Checking the solution: (-1.1296817774938751e-07, -3.5312337173515199e-07)
# tuniv = 672.30  Checking the solution:  -5.72840386237e-13
# Fold-change in tumor size: 0.10
# * Parameters: T = 74.0, Tbar = 54.0 (μ = 0.01351, μbar = 0.01852)
# Ending point: t = 33.60, x = 88.68%  Checking the solution: (-1.3370359439516628e-07, -8.5121395482150677e-08)
# tuniv = 671.12  Checking the solution:  1.51780532587e-11
# Fold-change in tumor size: 0.11
# * Parameters: T = 74.0, Tbar = 56.0 (μ = 0.01351, μbar = 0.01786)
# Ending point: t = 33.73, x = 89.01%  Checking the solution: (-1.8055203959021774e-08, -4.8189587032371317e-09)
# tuniv = 670.36  Checking the solution:  -3.80900172514e-13
# Fold-change in tumor size: 0.11
# * Parameters: T = 74.0, Tbar = 58.0 (μ = 0.01351, μbar = 0.01724)
# Ending point: t = 33.99, x = 89.32%  Checking the solution: (-1.2964438873289295e-07, -7.4277445433851649e-07)
# tuniv = 671.64  Checking the solution:  1.18710180574e-11
# Fold-change in tumor size: 0.12
# * Parameters: T = 74.0, Tbar = 60.0 (μ = 0.01351, μbar = 0.01667)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 34.12, x = 89.61%  Checking the solution: (-1.8931438088420223e-07, -7.0246684835526983e-07)
# tuniv = 671.07  Checking the solution:  4.26138291321e-13
# Fold-change in tumor size: 0.13
# * Parameters: T = 74.0, Tbar = 62.0 (μ = 0.01351, μbar = 0.01613)
# Ending point: t = 34.24, x = 89.89%  Checking the solution: (-2.2862635025210898e-07, -6.6477370750190809e-07)
# tuniv = 670.51  Checking the solution:  3.6432627748e-12
# Fold-change in tumor size: 0.14
# * Parameters: T = 74.0, Tbar = 64.0 (μ = 0.01351, μbar = 0.01562)
# Ending point: t = 34.20, x = 90.15%  Checking the solution: (-2.1969037825655551e-07, 2.0076431031754182e-07)
# tuniv = 667.69  Checking the solution:  5.66377014732e-11
# Fold-change in tumor size: 0.14
# * Parameters: T = 74.0, Tbar = 66.0 (μ = 0.01351, μbar = 0.01515)
# Ending point: t = 34.35, x = 90.40%  Checking the solution: (-2.1358160247018706e-08, -2.0616899726688898e-08)
# tuniv = 667.84  Checking the solution:  4.37691549671e-13
# Fold-change in tumor size: 0.15
# * Parameters: T = 74.0, Tbar = 68.0 (μ = 0.01351, μbar = 0.01471)
# Ending point: t = 34.46, x = 90.64%  Checking the solution: (-1.686425602488428e-08, -3.4157324237779317e-08)
# tuniv = 667.41  Checking the solution:  5.74844338797e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 74.0, Tbar = 70.0 (μ = 0.01351, μbar = 0.01429)
# Ending point: t = 34.59, x = 90.87%  Checking the solution: (-1.6587920205682195e-08, -1.2262585809215029e-07)
# tuniv = 667.21  Checking the solution:  3.12735948249e-14
# Fold-change in tumor size: 0.17
# * Parameters: T = 74.0, Tbar = 72.0 (μ = 0.01351, μbar = 0.01389)
# Ending point: t = 34.66, x = 91.08%  Checking the solution: (-9.9520333651532261e-14, -7.2170624921037817e-15)
# tuniv = 666.38  Checking the solution:  -4.00148785634e-11
# Fold-change in tumor size: 0.17
# * Parameters: T = 74.0, Tbar = 74.0 (μ = 0.01351, μbar = 0.01351)
# Ending point: t = 34.76, x = 91.29%  Checking the solution: (-2.9141859298555161e-13, -7.5088476763914758e-13)
# tuniv = 665.93  Checking the solution:  2.76987349723e-10
# Fold-change in tumor size: 0.18
# * Parameters: T = 74.0, Tbar = 76.0 (μ = 0.01351, μbar = 0.01316)
# Ending point: t = 34.85, x = 91.48%  Checking the solution: (-3.1312094844054839e-13, -2.2702331379655136e-15)
# tuniv = 665.49  Checking the solution:  -1.96024585453e-11
# Fold-change in tumor size: 0.19
# * Parameters: T = 74.0, Tbar = 78.0 (μ = 0.01351, μbar = 0.01282)
# Ending point: t = 34.97, x = 91.67%  Checking the solution: (-2.4141415568178585e-08, -1.5238902950945848e-07)
# tuniv = 665.56  Checking the solution:  1.07179543019e-12
# Fold-change in tumor size: 0.20
# * Parameters: T = 74.0, Tbar = 80.0 (μ = 0.01351, μbar = 0.01250)
# Ending point: t = 35.01, x = 91.85%  Checking the solution: (-9.58334523017646e-09, 3.4410385422375013e-08)
# tuniv = 664.52  Checking the solution:  -7.69320718241e-12
# Fold-change in tumor size: 0.20
# * Parameters: T = 74.0, Tbar = 82.0 (μ = 0.01351, μbar = 0.01220)
# Ending point: t = 35.21, x = 92.02%  Checking the solution: (-3.7682347992305901e-08, -4.2324061484856415e-07)
# tuniv = 665.64  Checking the solution:  2.53061460675e-13
# Fold-change in tumor size: 0.21
# * Parameters: T = 74.0, Tbar = 84.0 (μ = 0.01351, μbar = 0.01190)
# Ending point: t = 35.16, x = 92.18%  Checking the solution: (-2.6188346036876142e-08, 8.0899552324208219e-08)
# tuniv = 663.53  Checking the solution:  7.28579557796e-11
# Fold-change in tumor size: 0.22
# * Parameters: T = 74.0, Tbar = 86.0 (μ = 0.01351, μbar = 0.01163)
# Ending point: t = 35.26, x = 92.34%  Checking the solution: (1.0533659805577951e-13, -1.0957199718518056e-14)
# tuniv = 663.43  Checking the solution:  -1.25219695724e-11
# Fold-change in tumor size: 0.23
# * Parameters: T = 74.0, Tbar = 88.0 (μ = 0.01351, μbar = 0.01136)
# Ending point: t = 35.33, x = 92.49%  Checking the solution: (-7.6633499065968179e-13, -2.8242745117269834e-14)
# tuniv = 663.04  Checking the solution:  5.47698275621e-11
# Fold-change in tumor size: 0.23
# * Parameters: T = 74.0, Tbar = 90.0 (μ = 0.01351, μbar = 0.01111)
# Ending point: t = 35.40, x = 92.64%  Checking the solution: (-1.8611009215059905e-08, -1.1340927439510277e-08)
# tuniv = 662.70  Checking the solution:  -1.17582887871e-11
# Fold-change in tumor size: 0.24
# * Parameters: T = 74.0, Tbar = 92.0 (μ = 0.01351, μbar = 0.01087)
# Ending point: t = 35.47, x = 92.78%  Checking the solution: (-1.6091422530946659e-12, 2.5911905247460256e-13)
# tuniv = 662.28  Checking the solution:  -7.08179348496e-12
# Fold-change in tumor size: 0.25
# * Parameters: T = 74.0, Tbar = 94.0 (μ = 0.01351, μbar = 0.01064)
# Ending point: t = 35.53, x = 92.91%  Checking the solution: (-1.162924562144067e-13, -1.272367511765157e-14)
# tuniv = 661.91  Checking the solution:  1.55140886249e-10
# Fold-change in tumor size: 0.25
# * Parameters: T = 74.0, Tbar = 96.0 (μ = 0.01351, μbar = 0.01042)
# Ending point: t = 35.60, x = 93.04%  Checking the solution: (-4.6697317380478964e-14, -3.4340617195434185e-15)
# tuniv = 661.54  Checking the solution:  -2.25033880419e-12
# Fold-change in tumor size: 0.26
# * Parameters: T = 74.0, Tbar = 98.0 (μ = 0.01351, μbar = 0.01020)
# Ending point: t = 35.66, x = 93.17%  Checking the solution: (-1.2663867963114797e-13, -1.2281332409101561e-14)
# tuniv = 661.18  Checking the solution:  1.15612242002e-11
# Fold-change in tumor size: 0.27
# * Parameters: T = 74.0, Tbar = 100.0 (μ = 0.01351, μbar = 0.01000)
# Ending point: t = 35.72, x = 93.29%  Checking the solution: (5.5890583997567858e-14, 5.5612756375698109e-15)
# tuniv = 660.83  Checking the solution:  5.59302604231e-13
# Fold-change in tumor size: 0.27
# * Parameters: T = 74.0, Tbar = 102.0 (μ = 0.01351, μbar = 0.00980)
# Ending point: t = 35.77, x = 93.40%  Checking the solution: (-2.6960403700526268e-13, -3.7723738341929814e-12)
# tuniv = 660.49  Checking the solution:  2.11335029338e-12
# Fold-change in tumor size: 0.28
# * Parameters: T = 74.0, Tbar = 104.0 (μ = 0.01351, μbar = 0.00962)
# Ending point: t = 35.85, x = 93.52%  Checking the solution: (-7.8032025065925373e-09, -7.0768042845897641e-08)
# tuniv = 660.45  Checking the solution:  3.24018589737e-13
# Fold-change in tumor size: 0.29
# * Parameters: T = 74.0, Tbar = 106.0 (μ = 0.01351, μbar = 0.00943)
# Ending point: t = 35.89, x = 93.62%  Checking the solution: (-1.4313230722161912e-08, -3.1830240843285526e-09)
# tuniv = 659.82  Checking the solution:  -4.34825786488e-13
# Fold-change in tumor size: 0.29
# * Parameters: T = 74.0, Tbar = 108.0 (μ = 0.01351, μbar = 0.00926)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 35.96, x = 93.73%  Checking the solution: (-3.9541661666496727e-09, -6.8075189448955761e-08)
# tuniv = 659.78  Checking the solution:  -5.50259837695e-12
# Fold-change in tumor size: 0.30
# * Parameters: T = 74.0, Tbar = 110.0 (μ = 0.01351, μbar = 0.00909)
# Ending point: t = 36.00, x = 93.83%  Checking the solution: (-8.6596836419873814e-09, -2.8299591294117481e-08)
# tuniv = 659.28  Checking the solution:  -7.06216335411e-13
# Fold-change in tumor size: 0.30
# * Parameters: T = 74.0, Tbar = 112.0 (μ = 0.01351, μbar = 0.00893)
# Ending point: t = 36.07, x = 93.93%  Checking the solution: (-1.3587727785307715e-08, -7.9927878478765449e-08)
# tuniv = 659.19  Checking the solution:  1.69599612132e-11
# Fold-change in tumor size: 0.31
# * Parameters: T = 74.0, Tbar = 114.0 (μ = 0.01351, μbar = 0.00877)
# Ending point: t = 36.10, x = 94.02%  Checking the solution: (-1.8852863187758984e-08, -3.3824752302035432e-08)
# tuniv = 658.67  Checking the solution:  -7.85094211864e-13
# Fold-change in tumor size: 0.32
# * Parameters: T = 74.0, Tbar = 116.0 (μ = 0.01351, μbar = 0.00862)
# Ending point: t = 36.14, x = 94.12%  Checking the solution: (-2.0381775969764323e-08, -8.6309841602408074e-09)
# tuniv = 658.24  Checking the solution:  1.05485065127e-12
# Fold-change in tumor size: 0.32
# * Parameters: T = 74.0, Tbar = 118.0 (μ = 0.01351, μbar = 0.00847)
# Ending point: t = 36.22, x = 94.21%  Checking the solution: (-2.311905292593895e-08, -1.0422433796654705e-07)
# tuniv = 658.39  Checking the solution:  4.70975081851e-12
# Fold-change in tumor size: 0.33
# * Parameters: T = 74.0, Tbar = 120.0 (μ = 0.01351, μbar = 0.00833)
# Ending point: t = 36.27, x = 94.29%  Checking the solution: (-2.563317498617375e-08, -1.2798865065957735e-07)
# tuniv = 658.21  Checking the solution:  2.20595763878e-12
# Fold-change in tumor size: 0.33
# * Parameters: T = 72.0, Tbar = 4.0 (μ = 0.01389, μbar = 0.25000)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 20.87, x = 46.70%  Checking the solution: (1.3698098644959744e-12, 1.4365459501791251e-13)
# tuniv = 697.53  Checking the solution:  5.17736548078e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 6.0 (μ = 0.01389, μbar = 0.16667)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.58, x = 54.77%  Checking the solution: (-4.7495121541498883e-07, 1.0969652649347322e-07)
# tuniv = 694.99  Checking the solution:  -3.13706005617e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 8.0 (μ = 0.01389, μbar = 0.12500)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 23.94, x = 60.43%  Checking the solution: (-1.0212819702466809e-07, -1.819939225635326e-08)
# tuniv = 692.99  Checking the solution:  1.35885469543e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 10.0 (μ = 0.01389, μbar = 0.10000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 25.05, x = 64.70%  Checking the solution: (-3.554437103412615e-08, -2.2315884698864229e-07)
# tuniv = 691.33  Checking the solution:  -1.44520645451e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 12.0 (μ = 0.01389, μbar = 0.08333)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 25.98, x = 68.06%  Checking the solution: (-5.8063347430983542e-08, -1.6498457454038019e-08)
# tuniv = 689.55  Checking the solution:  -5.31587100727e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 14.0 (μ = 0.01389, μbar = 0.07143)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 26.77, x = 70.79%  Checking the solution: (-4.6247248104652406e-08, -5.5347549464473619e-08)
# tuniv = 688.13  Checking the solution:  4.95339880224e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 16.0 (μ = 0.01389, μbar = 0.06250)
# Ending point: t = 27.46, x = 73.06%  Checking the solution: (-7.8663313252859589e-08, -1.0120219687176536e-07)
# tuniv = 686.84  Checking the solution:  1.14794979078e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 72.0, Tbar = 18.0 (μ = 0.01389, μbar = 0.05556)
# Ending point: t = 28.06, x = 74.99%  Checking the solution: (-1.1276642802498403e-07, 1.771398692338828e-07)
# tuniv = 685.31  Checking the solution:  -7.69787011912e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 72.0, Tbar = 20.0 (μ = 0.01389, μbar = 0.05000)
# Ending point: t = 28.62, x = 76.64%  Checking the solution: (-1.7910134165471433e-07, -3.1282363521738092e-07)
# tuniv = 684.72  Checking the solution:  7.85121967439e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 72.0, Tbar = 22.0 (μ = 0.01389, μbar = 0.04545)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 29.10, x = 78.08%  Checking the solution: (-1.5294147358100215e-07, -3.1703215547350535e-07)
# tuniv = 683.67  Checking the solution:  6.79375644283e-11
# Fold-change in tumor size: 0.01
# * Parameters: T = 72.0, Tbar = 24.0 (μ = 0.01389, μbar = 0.04167)
# Ending point: t = 29.52, x = 79.34%  Checking the solution: (-9.6661133280493902e-14, -2.2633252407906742e-15)
# tuniv = 682.26  Checking the solution:  2.62204147283e-12
# Fold-change in tumor size: 0.02
# * Parameters: T = 72.0, Tbar = 26.0 (μ = 0.01389, μbar = 0.03846)
# Ending point: t = 29.92, x = 80.46%  Checking the solution: (-9.1550689350340299e-08, -7.5157483549291305e-08)
# tuniv = 681.41  Checking the solution:  6.76542155631e-13
# Fold-change in tumor size: 0.02
# * Parameters: T = 72.0, Tbar = 28.0 (μ = 0.01389, μbar = 0.03571)
# Ending point: t = 30.28, x = 81.46%  Checking the solution: (-2.2102871183282053e-08, 6.9722722959849682e-11)
# tuniv = 680.39  Checking the solution:  3.84919873753e-12
# Fold-change in tumor size: 0.02
# * Parameters: T = 72.0, Tbar = 30.0 (μ = 0.01389, μbar = 0.03333)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 30.62, x = 82.36%  Checking the solution: (-1.3178662221804504e-07, -2.1428726278886165e-07)
# tuniv = 679.85  Checking the solution:  -8.60944648906e-12
# Fold-change in tumor size: 0.03
# * Parameters: T = 72.0, Tbar = 32.0 (μ = 0.01389, μbar = 0.03125)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 30.91, x = 83.18%  Checking the solution: (-1.8519442825542072e-07, 6.3944925938170887e-09)
# tuniv = 678.68  Checking the solution:  -9.70315494619e-12
# Fold-change in tumor size: 0.03
# * Parameters: T = 72.0, Tbar = 34.0 (μ = 0.01389, μbar = 0.02941)
# Ending point: t = 31.21, x = 83.92%  Checking the solution: (-2.3954513371889563e-07, -1.8546056371884843e-07)
# tuniv = 678.21  Checking the solution:  -2.47583897828e-12
# Fold-change in tumor size: 0.04
# * Parameters: T = 72.0, Tbar = 36.0 (μ = 0.01389, μbar = 0.02778)
# Ending point: t = 31.43, x = 84.59%  Checking the solution: (-9.9579193908215811e-08, 2.786988549118774e-07)
# tuniv = 676.63  Checking the solution:  -1.65527765106e-11
# Fold-change in tumor size: 0.05
# * Parameters: T = 72.0, Tbar = 38.0 (μ = 0.01389, μbar = 0.02632)
# Ending point: t = 31.70, x = 85.21%  Checking the solution: (2.4578114642527602e-13, 2.0193950600734261e-14)
# tuniv = 676.40  Checking the solution:  3.59755419899e-11
# Fold-change in tumor size: 0.05
# * Parameters: T = 72.0, Tbar = 40.0 (μ = 0.01389, μbar = 0.02500)
# Ending point: t = 31.92, x = 85.78%  Checking the solution: (1.9559808823619781e-13, 8.1307865733225823e-14)
# tuniv = 675.69  Checking the solution:  -7.02465169367e-12
# Fold-change in tumor size: 0.06
# * Parameters: T = 72.0, Tbar = 42.0 (μ = 0.01389, μbar = 0.02381)
# Ending point: t = 32.14, x = 86.31%  Checking the solution: (3.2056808921786251e-16, 1.5165678339550935e-17)
# tuniv = 675.01  Checking the solution:  5.61894628048e-12
# Fold-change in tumor size: 0.07
# * Parameters: T = 72.0, Tbar = 44.0 (μ = 0.01389, μbar = 0.02273)
# Ending point: t = 32.34, x = 86.80%  Checking the solution: (-2.4629347769155457e-13, -1.5674603077869087e-14)
# tuniv = 674.35  Checking the solution:  -3.32505550871e-12
# Fold-change in tumor size: 0.07
# * Parameters: T = 72.0, Tbar = 46.0 (μ = 0.01389, μbar = 0.02174)
# Ending point: t = 32.53, x = 87.25%  Checking the solution: (2.9836095210124605e-14, 2.4797413415290066e-15)
# tuniv = 673.71  Checking the solution:  7.83705739194e-12
# Fold-change in tumor size: 0.08
# * Parameters: T = 72.0, Tbar = 48.0 (μ = 0.01389, μbar = 0.02083)
# Ending point: t = 32.71, x = 87.68%  Checking the solution: (-2.1561675671485929e-08, -1.2999759741263304e-08)
# tuniv = 673.12  Checking the solution:  -6.67833843782e-12
# Fold-change in tumor size: 0.09
# * Parameters: T = 72.0, Tbar = 50.0 (μ = 0.01389, μbar = 0.02000)
# Ending point: t = 32.88, x = 88.07%  Checking the solution: (-7.127051878910119e-08, -8.4437379319551387e-08)
# tuniv = 672.69  Checking the solution:  9.11293956962e-12
# Fold-change in tumor size: 0.10
# * Parameters: T = 72.0, Tbar = 52.0 (μ = 0.01389, μbar = 0.01923)
# Ending point: t = 33.04, x = 88.44%  Checking the solution: (-1.0546566255719198e-07, -5.2872361697407923e-08)
# tuniv = 672.04  Checking the solution:  -1.99922023381e-12
# Fold-change in tumor size: 0.10
# * Parameters: T = 72.0, Tbar = 54.0 (μ = 0.01389, μbar = 0.01852)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 33.19, x = 88.79%  Checking the solution: (-1.2795127978096238e-07, -6.0762826972639414e-08)
# tuniv = 671.49  Checking the solution:  1.57714119542e-11
# Fold-change in tumor size: 0.11
# * Parameters: T = 72.0, Tbar = 56.0 (μ = 0.01389, μbar = 0.01786)
# Ending point: t = 33.35, x = 89.12%  Checking the solution: (-1.2668635116906834e-07, -1.8870948034902847e-07)
# tuniv = 671.27  Checking the solution:  -1.80225973034e-12
# Fold-change in tumor size: 0.12
# * Parameters: T = 72.0, Tbar = 58.0 (μ = 0.01389, μbar = 0.01724)
# Ending point: t = 33.49, x = 89.43%  Checking the solution: (-8.8798078036902807e-08, -1.8544421201249948e-07)
# tuniv = 670.73  Checking the solution:  -9.61756368989e-12
# Fold-change in tumor size: 0.13
# * Parameters: T = 72.0, Tbar = 60.0 (μ = 0.01389, μbar = 0.01667)
# Ending point: t = 33.61, x = 89.72%  Checking the solution: (-1.4499790727258983e-07, -1.5618948469492601e-07)
# tuniv = 670.15  Checking the solution:  5.35643751576e-12
# Fold-change in tumor size: 0.13
# * Parameters: T = 72.0, Tbar = 62.0 (μ = 0.01389, μbar = 0.01613)
# Ending point: t = 33.80, x = 90.00%  Checking the solution: (-2.0253060521534216e-07, -4.9562782949825698e-07)
# tuniv = 670.53  Checking the solution:  -1.34909791671e-12
# Fold-change in tumor size: 0.14
# * Parameters: T = 72.0, Tbar = 64.0 (μ = 0.01389, μbar = 0.01562)
# Ending point: t = 33.85, x = 90.26%  Checking the solution: (-2.1225328299224023e-07, -1.2948179736114703e-07)
# tuniv = 669.09  Checking the solution:  -5.85797382824e-12
# Fold-change in tumor size: 0.15
# * Parameters: T = 72.0, Tbar = 66.0 (μ = 0.01389, μbar = 0.01515)
# Ending point: t = 33.94, x = 90.50%  Checking the solution: (-2.7452150626230531e-14, 7.2229506224755546e-13)
# tuniv = 668.24  Checking the solution:  3.4987568398e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 72.0, Tbar = 68.0 (μ = 0.01389, μbar = 0.01471)
# Ending point: t = 34.04, x = 90.74%  Checking the solution: (5.7014641700656025e-14, -3.6336511016290246e-15)
# tuniv = 667.76  Checking the solution:  3.45556916415e-15
# Fold-change in tumor size: 0.16
# * Parameters: T = 72.0, Tbar = 70.0 (μ = 0.01389, μbar = 0.01429)
# Ending point: t = 34.15, x = 90.96%  Checking the solution: (-6.4347329010533982e-09, -3.2181758110189019e-08)
# tuniv = 667.40  Checking the solution:  -4.20530277268e-12
# Fold-change in tumor size: 0.17
# * Parameters: T = 72.0, Tbar = 72.0 (μ = 0.01389, μbar = 0.01389)
# Ending point: t = 34.24, x = 91.18%  Checking the solution: (3.9488008369626456e-13, 2.9104383174162915e-14)
# tuniv = 666.84  Checking the solution:  -6.36234814833e-12
# Fold-change in tumor size: 0.18
# * Parameters: T = 72.0, Tbar = 74.0 (μ = 0.01389, μbar = 0.01351)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 34.34, x = 91.38%  Checking the solution: (-7.7773551607072118e-09, -3.4534820352590957e-09)
# tuniv = 666.41  Checking the solution:  2.06779038336e-15
# Fold-change in tumor size: 0.19
# * Parameters: T = 72.0, Tbar = 76.0 (μ = 0.01389, μbar = 0.01316)
# Ending point: t = 34.43, x = 91.57%  Checking the solution: (2.6058185540318813e-13, -1.0341344971271895e-13)
# tuniv = 665.96  Checking the solution:  -1.06037401082e-11
# Fold-change in tumor size: 0.20
# * Parameters: T = 72.0, Tbar = 78.0 (μ = 0.01389, μbar = 0.01282)
# Ending point: t = 34.52, x = 91.76%  Checking the solution: (-5.6712706649891804e-09, -3.5322809230439284e-08)
# tuniv = 665.66  Checking the solution:  1.45801842821e-11
# Fold-change in tumor size: 0.20
# * Parameters: T = 72.0, Tbar = 80.0 (μ = 0.01389, μbar = 0.01250)
# Ending point: t = 34.60, x = 91.94%  Checking the solution: (-7.420323206897396e-09, -1.5209761096724196e-08)
# tuniv = 665.17  Checking the solution:  -1.99394528666e-11
# Fold-change in tumor size: 0.21
# * Parameters: T = 72.0, Tbar = 82.0 (μ = 0.01389, μbar = 0.01220)
# Ending point: t = 34.68, x = 92.10%  Checking the solution: (-1.3902629412368825e-08, -5.149647645034601e-09)
# tuniv = 664.73  Checking the solution:  1.72084568817e-15
# Fold-change in tumor size: 0.22
# * Parameters: T = 72.0, Tbar = 84.0 (μ = 0.01389, μbar = 0.01190)
# Ending point: t = 34.76, x = 92.27%  Checking the solution: (-2.1838857041106958e-08, 2.1595402775268906e-10)
# tuniv = 664.30  Checking the solution:  -3.12250225676e-15
# Fold-change in tumor size: 0.23
# * Parameters: T = 72.0, Tbar = 86.0 (μ = 0.01389, μbar = 0.01163)
# Ending point: t = 34.83, x = 92.42%  Checking the solution: (-1.3330146838699018e-08, -1.3700218600078923e-08)
# tuniv = 663.96  Checking the solution:  2.82367185189e-12
# Fold-change in tumor size: 0.23
# * Parameters: T = 72.0, Tbar = 88.0 (μ = 0.01389, μbar = 0.01136)
# Ending point: t = 34.90, x = 92.57%  Checking the solution: (-1.9102699700930884e-13, -8.8242940112883129e-15)
# tuniv = 663.52  Checking the solution:  -3.40005801291e-15
# Fold-change in tumor size: 0.24
# * Parameters: T = 72.0, Tbar = 90.0 (μ = 0.01389, μbar = 0.01111)
# Ending point: t = 34.97, x = 92.72%  Checking the solution: (-1.2819972113883615e-08, -4.4642060848037597e-10)
# tuniv = 663.14  Checking the solution:  9.05403529927e-12
# Fold-change in tumor size: 0.25
# * Parameters: T = 72.0, Tbar = 92.0 (μ = 0.01389, μbar = 0.01087)
# Ending point: t = 35.05, x = 92.86%  Checking the solution: (-8.0189844223096721e-09, -2.6824104402317445e-08)
# tuniv = 662.87  Checking the solution:  2.2018359358e-12
# Fold-change in tumor size: 0.25
# * Parameters: T = 72.0, Tbar = 94.0 (μ = 0.01389, μbar = 0.01064)
# Ending point: t = 35.10, x = 92.99%  Checking the solution: (-9.6358443035002539e-12, 2.4870852079211527e-11)
# tuniv = 662.40  Checking the solution:  4.92278440234e-11
# Fold-change in tumor size: 0.26
# * Parameters: T = 72.0, Tbar = 96.0 (μ = 0.01389, μbar = 0.01042)
# Ending point: t = 35.17, x = 93.12%  Checking the solution: (-2.0608145119724366e-13, -4.0337171765464294e-15)
# tuniv = 662.04  Checking the solution:  -4.14582118635e-11
# Fold-change in tumor size: 0.27
# * Parameters: T = 72.0, Tbar = 98.0 (μ = 0.01389, μbar = 0.01020)
# Ending point: t = 35.23, x = 93.24%  Checking the solution: (1.4315896023050388e-11, -9.0241181684767324e-12)
# tuniv = 661.68  Checking the solution:  -8.93590756945e-12
# Fold-change in tumor size: 0.27
# * Parameters: T = 72.0, Tbar = 100.0 (μ = 0.01389, μbar = 0.01000)
# Ending point: t = 35.29, x = 93.36%  Checking the solution: (-1.721755771072467e-13, 2.7457062374863776e-14)
# tuniv = 661.33  Checking the solution:  2.31945018747e-12
# Fold-change in tumor size: 0.28
# * Parameters: T = 72.0, Tbar = 102.0 (μ = 0.01389, μbar = 0.00980)
# Ending point: t = 35.34, x = 93.47%  Checking the solution: (-2.0797891118658464e-12, -7.4330070181038602e-13)
# tuniv = 660.99  Checking the solution:  2.984884475e-12
# Fold-change in tumor size: 0.29
# * Parameters: T = 72.0, Tbar = 104.0 (μ = 0.01389, μbar = 0.00962)
# Ending point: t = 35.40, x = 93.59%  Checking the solution: (-1.352896384297067e-13, -1.0765639047181427e-14)
# tuniv = 660.65  Checking the solution:  1.61441519875e-12
# Fold-change in tumor size: 0.29
# * Parameters: T = 72.0, Tbar = 106.0 (μ = 0.01389, μbar = 0.00943)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 35.45, x = 93.69%  Checking the solution: (-5.6166839668928257e-09, -8.0600545061616021e-10)
# tuniv = 660.32  Checking the solution:  6.37849842389e-12
# Fold-change in tumor size: 0.30
# * Parameters: T = 72.0, Tbar = 108.0 (μ = 0.01389, μbar = 0.00926)
# Ending point: t = 35.51, x = 93.80%  Checking the solution: (-2.3053510207594446e-08, -3.4830428564610053e-08)
# tuniv = 660.14  Checking the solution:  -3.0679573465e-12
# Fold-change in tumor size: 0.31
# * Parameters: T = 72.0, Tbar = 110.0 (μ = 0.01389, μbar = 0.00909)
# Ending point: t = 35.56, x = 93.90%  Checking the solution: (-5.491133276610969e-09, -7.1213675482126499e-09)
# tuniv = 659.70  Checking the solution:  -4.99600361081e-16
# Fold-change in tumor size: 0.31
# * Parameters: T = 72.0, Tbar = 112.0 (μ = 0.01389, μbar = 0.00893)
# Ending point: t = 35.60, x = 93.99%  Checking the solution: (-7.8869907835880486e-09, -3.796423010853578e-09)
# tuniv = 659.36  Checking the solution:  -5.51787782133e-13
# Fold-change in tumor size: 0.32
# * Parameters: T = 72.0, Tbar = 114.0 (μ = 0.01389, μbar = 0.00877)
# Ending point: t = 35.65, x = 94.09%  Checking the solution: (-1.2076132536240873e-08, 9.0639275150008569e-10)
# tuniv = 659.03  Checking the solution:  -7.74491581979e-13
# Fold-change in tumor size: 0.33
# * Parameters: T = 72.0, Tbar = 116.0 (μ = 0.01389, μbar = 0.00862)
# Ending point: t = 35.70, x = 94.18%  Checking the solution: (-1.6014481584532459e-08, -1.0522691296356908e-08)
# tuniv = 658.77  Checking the solution:  1.68060010353e-13
# Fold-change in tumor size: 0.33
# * Parameters: T = 72.0, Tbar = 118.0 (μ = 0.01389, μbar = 0.00847)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 35.74, x = 94.27%  Checking the solution: (-1.9272786222517601e-08, -3.7989196073783855e-10)
# tuniv = 658.42  Checking the solution:  8.17429457456e-13
# Fold-change in tumor size: 0.34
# * Parameters: T = 72.0, Tbar = 120.0 (μ = 0.01389, μbar = 0.00833)
# Ending point: t = 35.81, x = 94.35%  Checking the solution: (-2.1156919123244279e-08, -6.2233566344031763e-08)
# tuniv = 658.42  Checking the solution:  3.3919950182e-12
# Fold-change in tumor size: 0.34
# * Parameters: T = 70.0, Tbar = 4.0 (μ = 0.01429, μbar = 0.25000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 20.58, x = 47.05%  Checking the solution: (5.0300689720221559e-13, 3.9849274548448306e-14)
# tuniv = 697.83  Checking the solution:  -6.11080630541e-13
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 6.0 (μ = 0.01429, μbar = 0.16667)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.28, x = 55.10%  Checking the solution: (-3.4181623125732264e-07, -3.8512653170764152e-07)
# tuniv = 695.62  Checking the solution:  -2.44562703422e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 8.0 (μ = 0.01429, μbar = 0.12500)
# Ending point: t = 23.61, x = 60.75%  Checking the solution: (-5.1531784154909143e-08, 4.5031963811769696e-07)
# tuniv = 692.96  Checking the solution:  2.65587551951e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 10.0 (μ = 0.01429, μbar = 0.10000)
# Ending point: t = 24.73, x = 65.00%  Checking the solution: (-5.2381682665019076e-08, -9.654461680469814e-08)
# tuniv = 691.56  Checking the solution:  2.2561258417e-12
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 12.0 (μ = 0.01429, μbar = 0.08333)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 25.65, x = 68.34%  Checking the solution: (-5.4858049548852647e-08, -1.3460190572476287e-07)
# tuniv = 689.99  Checking the solution:  1.65439953403e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 14.0 (μ = 0.01429, μbar = 0.07143)
# Ending point: t = 26.44, x = 71.05%  Checking the solution: (-4.1157022945659084e-08, -1.6505817045384026e-07)
# tuniv = 688.58  Checking the solution:  2.89435836409e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 16.0 (μ = 0.01429, μbar = 0.06250)
# Ending point: t = 27.11, x = 73.31%  Checking the solution: (-3.0684821324748063e-08, 5.2585654941396634e-08)
# tuniv = 687.04  Checking the solution:  -1.81199361071e-11
# Fold-change in tumor size: 0.00
# * Parameters: T = 70.0, Tbar = 18.0 (μ = 0.01429, μbar = 0.05556)
# Ending point: t = 27.75, x = 75.22%  Checking the solution: (-1.2709194254166488e-07, -8.5204403387492618e-07)
# tuniv = 686.78  Checking the solution:  1.80458079035e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 70.0, Tbar = 20.0 (μ = 0.01429, μbar = 0.05000)
# Ending point: t = 28.28, x = 76.86%  Checking the solution: (-1.6311617791878246e-07, -7.2232518640255616e-07)
# tuniv = 685.55  Checking the solution:  -1.93808857851e-12
# Fold-change in tumor size: 0.01
# * Parameters: T = 70.0, Tbar = 22.0 (μ = 0.01429, μbar = 0.04545)
# Ending point: t = 28.74, x = 78.29%  Checking the solution: (-1.319059038195681e-07, -2.3948518800954272e-07)
# tuniv = 683.95  Checking the solution:  -4.36022745687e-15
# Fold-change in tumor size: 0.01
# * Parameters: T = 70.0, Tbar = 24.0 (μ = 0.01429, μbar = 0.04167)
# Ending point: t = 29.15, x = 79.54%  Checking the solution: (-2.1329978256746929e-13, -1.4035594979244805e-14)
# tuniv = 682.64  Checking the solution:  4.35482205852e-12
# Fold-change in tumor size: 0.02
# * Parameters: T = 70.0, Tbar = 26.0 (μ = 0.01429, μbar = 0.03846)
# Ending point: t = 29.54, x = 80.66%  Checking the solution: (-3.0007471201999808e-12, -7.6410384992963285e-13)
# tuniv = 681.69  Checking the solution:  3.15025783237e-15
# Fold-change in tumor size: 0.02
# * Parameters: T = 70.0, Tbar = 28.0 (μ = 0.01429, μbar = 0.03571)
# Ending point: t = 29.90, x = 81.65%  Checking the solution: (-8.9616562702379943e-09, -5.2914984329139311e-08)
# tuniv = 680.86  Checking the solution:  -4.10312062105e-12
# Fold-change in tumor size: 0.03
# * Parameters: T = 70.0, Tbar = 30.0 (μ = 0.01429, μbar = 0.03333)
# Ending point: t = 30.23, x = 82.54%  Checking the solution: (7.2184415258016218e-13, 4.8329390440054864e-14)
# tuniv = 679.92  Checking the solution:  -1.759509205e-12
# Fold-change in tumor size: 0.03
# * Parameters: T = 70.0, Tbar = 32.0 (μ = 0.01429, μbar = 0.03125)
# Ending point: t = 30.54, x = 83.35%  Checking the solution: (-1.9961527176801386e-07, -1.4401708390635579e-07)
# tuniv = 679.33  Checking the solution:  -5.82971171337e-12
# Fold-change in tumor size: 0.04
# * Parameters: T = 70.0, Tbar = 34.0 (μ = 0.01429, μbar = 0.02941)
# Ending point: t = 30.78, x = 84.08%  Checking the solution: (-2.3437767860234118e-07, 3.1412393667053467e-07)
# tuniv = 677.76  Checking the solution:  4.69312089191e-14
# Fold-change in tumor size: 0.04
# * Parameters: T = 70.0, Tbar = 36.0 (μ = 0.01429, μbar = 0.02778)
# Ending point: t = 31.13, x = 84.75%  Checking the solution: (-1.053624991831635e-07, -6.4723761880561579e-07)
# tuniv = 678.66  Checking the solution:  -2.98846711266e-12
# Fold-change in tumor size: 0.05
# * Parameters: T = 70.0, Tbar = 38.0 (μ = 0.01429, μbar = 0.02632)
# Ending point: t = 31.30, x = 85.37%  Checking the solution: (2.6419048426793573e-13, -4.9302363150183301e-13)
# tuniv = 676.82  Checking the solution:  2.89356039129e-12
# Fold-change in tumor size: 0.06
# * Parameters: T = 70.0, Tbar = 40.0 (μ = 0.01429, μbar = 0.02500)
# Ending point: t = 31.53, x = 85.93%  Checking the solution: (-1.1290931331445295e-12, -8.723752489849319e-14)
# tuniv = 676.12  Checking the solution:  -1.4872603149e-11
# Fold-change in tumor size: 0.06
# * Parameters: T = 70.0, Tbar = 42.0 (μ = 0.01429, μbar = 0.02381)
# Ending point: t = 31.74, x = 86.45%  Checking the solution: (-8.8972521536422652e-13, -6.7394439433562062e-14)
# tuniv = 675.44  Checking the solution:  2.50320597583e-15
# Fold-change in tumor size: 0.07
# * Parameters: T = 70.0, Tbar = 44.0 (μ = 0.01429, μbar = 0.02273)
# Ending point: t = 31.94, x = 86.94%  Checking the solution: (1.4215265215758357e-14, -1.5627825203911291e-14)
# tuniv = 674.78  Checking the solution:  -3.0253577421e-15
# Fold-change in tumor size: 0.08
# * Parameters: T = 70.0, Tbar = 46.0 (μ = 0.01429, μbar = 0.02174)
# Ending point: t = 32.12, x = 87.39%  Checking the solution: (-1.6272318609483315e-13, -6.4049219860253358e-15)
# tuniv = 674.15  Checking the solution:  -5.12383191431e-12
# Fold-change in tumor size: 0.08
# * Parameters: T = 70.0, Tbar = 48.0 (μ = 0.01429, μbar = 0.02083)
# Ending point: t = 32.29, x = 87.81%  Checking the solution: (-1.9034711713292131e-08, 2.1031709958932805e-08)
# tuniv = 673.49  Checking the solution:  -1.37786171361e-11
# Fold-change in tumor size: 0.09
# * Parameters: T = 70.0, Tbar = 50.0 (μ = 0.01429, μbar = 0.02000)
# Ending point: t = 32.50, x = 88.20%  Checking the solution: (-6.7379384633068561e-08, -2.4020511439863866e-07)
# tuniv = 673.48  Checking the solution:  4.95052610017e-11
# Fold-change in tumor size: 0.10
# * Parameters: T = 70.0, Tbar = 52.0 (μ = 0.01429, μbar = 0.01923)
# Ending point: t = 32.62, x = 88.57%  Checking the solution: (-1.0027129511115589e-07, -1.7946743504010983e-08)
# tuniv = 672.40  Checking the solution:  -1.32119593044e-11
# Fold-change in tumor size: 0.11
# * Parameters: T = 70.0, Tbar = 54.0 (μ = 0.01429, μbar = 0.01852)
# Ending point: t = 32.83, x = 88.91%  Checking the solution: (-1.275011047876439e-07, -4.3645488866156981e-07)
# tuniv = 672.83  Checking the solution:  -2.90045765183e-12
# Fold-change in tumor size: 0.12
# * Parameters: T = 70.0, Tbar = 56.0 (μ = 0.01429, μbar = 0.01786)
# Ending point: t = 33.05, x = 89.24%  Checking the solution: (-1.8388301293666001e-07, -8.8444014037258086e-07)
# tuniv = 673.34  Checking the solution:  9.19708753599e-13
# Fold-change in tumor size: 0.12
# * Parameters: T = 70.0, Tbar = 58.0 (μ = 0.01429, μbar = 0.01724)
# Ending point: t = 33.11, x = 89.54%  Checking the solution: (-8.9099646170203128e-08, -4.3520850217899776e-07)
# tuniv = 671.81  Checking the solution:  -2.46107561414e-12
# Fold-change in tumor size: 0.13
# * Parameters: T = 70.0, Tbar = 60.0 (μ = 0.01429, μbar = 0.01667)
# Ending point: t = 33.26, x = 89.83%  Checking the solution: (-1.5585698875318159e-07, -5.2797830209587833e-07)
# tuniv = 671.55  Checking the solution:  -1.70252423271e-11
# Fold-change in tumor size: 0.14
# * Parameters: T = 70.0, Tbar = 62.0 (μ = 0.01429, μbar = 0.01613)
# Ending point: t = 33.46, x = 90.10%  Checking the solution: (-2.4662330520553974e-07, -9.4549316347992756e-07)
# tuniv = 672.09  Checking the solution:  -1.23917542894e-12
# Fold-change in tumor size: 0.15
# * Parameters: T = 70.0, Tbar = 64.0 (μ = 0.01429, μbar = 0.01562)
# Ending point: t = 33.55, x = 90.36%  Checking the solution: (-2.5300667579705946e-07, -7.8101109123550599e-07)
# tuniv = 671.26  Checking the solution:  -5.69750496782e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 70.0, Tbar = 66.0 (μ = 0.01429, μbar = 0.01515)
# Ending point: t = 33.51, x = 90.61%  Checking the solution: (-1.8599755564324993e-08, -4.1944416420987811e-09)
# tuniv = 668.72  Checking the solution:  -1.10238901341e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 70.0, Tbar = 68.0 (μ = 0.01429, μbar = 0.01471)
# Ending point: t = 33.62, x = 90.84%  Checking the solution: (6.4267743958654894e-15, 1.8457783237579339e-16)
# tuniv = 668.24  Checking the solution:  2.07629746729e-12
# Fold-change in tumor size: 0.17
# * Parameters: T = 70.0, Tbar = 70.0 (μ = 0.01429, μbar = 0.01429)
# Ending point: t = 33.78, x = 91.06%  Checking the solution: (-2.0923586516184207e-08, -2.9739981574271382e-07)
# tuniv = 668.66  Checking the solution:  5.18269593908e-11
# Fold-change in tumor size: 0.18
# * Parameters: T = 70.0, Tbar = 72.0 (μ = 0.01429, μbar = 0.01389)
# Ending point: t = 33.82, x = 91.27%  Checking the solution: (-7.6939975220804881e-09, -3.5456927054187713e-08)
# tuniv = 667.43  Checking the solution:  -1.1636386299e-12
# Fold-change in tumor size: 0.19
# * Parameters: T = 70.0, Tbar = 74.0 (μ = 0.01429, μbar = 0.01351)
# Ending point: t = 33.86, x = 91.47%  Checking the solution: (-1.1853277389383236e-08, 2.2228935757668228e-07)
# tuniv = 666.15  Checking the solution:  7.39314165443e-12
# Fold-change in tumor size: 0.19
# * Parameters: T = 70.0, Tbar = 76.0 (μ = 0.01429, μbar = 0.01316)
# Ending point: t = 34.00, x = 91.67%  Checking the solution: (-1.0931510342142155e-14, -3.1199243697655659e-16)
# tuniv = 666.45  Checking the solution:  -2.59661181445e-11
# Fold-change in tumor size: 0.20
# * Parameters: T = 70.0, Tbar = 78.0 (μ = 0.01429, μbar = 0.01282)
# Ending point: t = 34.08, x = 91.85%  Checking the solution: (-9.3792709567692891e-14, -6.8818357348857507e-15)
# tuniv = 666.03  Checking the solution:  1.63144359133e-11
# Fold-change in tumor size: 0.21
# * Parameters: T = 70.0, Tbar = 80.0 (μ = 0.01429, μbar = 0.01250)
# Ending point: t = 34.16, x = 92.02%  Checking the solution: (-3.10413349185272e-08, 3.9932679422289855e-08)
# tuniv = 665.47  Checking the solution:  -8.87151463402e-13
# Fold-change in tumor size: 0.22
# * Parameters: T = 70.0, Tbar = 82.0 (μ = 0.01429, μbar = 0.01220)
# Ending point: t = 34.24, x = 92.19%  Checking the solution: (-5.685693323664511e-09, 5.0314889477164025e-09)
# tuniv = 665.18  Checking the solution:  5.53321277685e-13
# Fold-change in tumor size: 0.23
# * Parameters: T = 70.0, Tbar = 84.0 (μ = 0.01429, μbar = 0.01190)
# Ending point: t = 34.44, x = 92.35%  Checking the solution: (-4.0480776937378644e-08, -4.8834449229332675e-07)
# tuniv = 666.45  Checking the solution:  8.3960373376e-12
# Fold-change in tumor size: 0.23
# * Parameters: T = 70.0, Tbar = 86.0 (μ = 0.01429, μbar = 0.01163)
# Ending point: t = 34.40, x = 92.51%  Checking the solution: (-2.2427157231150877e-08, -1.2062045961305021e-08)
# tuniv = 664.45  Checking the solution:  -4.65034954988e-12
# Fold-change in tumor size: 0.24
# * Parameters: T = 70.0, Tbar = 88.0 (μ = 0.01429, μbar = 0.01136)
# Ending point: t = 34.48, x = 92.66%  Checking the solution: (-1.9612204889402067e-08, -3.5353373471355057e-08)
# tuniv = 664.16  Checking the solution:  -4.81180373324e-12
# Fold-change in tumor size: 0.25
# * Parameters: T = 70.0, Tbar = 90.0 (μ = 0.01429, μbar = 0.01111)
# Ending point: t = 34.53, x = 92.80%  Checking the solution: (-6.371372003664659e-14, -3.4564451744125215e-15)
# tuniv = 663.65  Checking the solution:  6.6100597218e-12
# Fold-change in tumor size: 0.26
# * Parameters: T = 70.0, Tbar = 92.0 (μ = 0.01429, μbar = 0.01087)
# Ending point: t = 34.60, x = 92.93%  Checking the solution: (-2.1554766137800251e-08, -9.5338954739787799e-09)
# tuniv = 663.31  Checking the solution:  -6.19370943422e-11
# Fold-change in tumor size: 0.26
# * Parameters: T = 70.0, Tbar = 94.0 (μ = 0.01429, μbar = 0.01064)
# Ending point: t = 34.66, x = 93.07%  Checking the solution: (3.274298585061091e-11, 7.1041732886164522e-11)
# tuniv = 662.91  Checking the solution:  7.45791622903e-11
# Fold-change in tumor size: 0.27
# * Parameters: T = 70.0, Tbar = 96.0 (μ = 0.01429, μbar = 0.01042)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 34.73, x = 93.19%  Checking the solution: (-3.9792945565622083e-13, -4.7400821637430487e-16)
# tuniv = 662.55  Checking the solution:  -6.75898226277e-11
# ...
# * Parameters: T = 4.0, Tbar = 20.0 (μ = 0.25000, μbar = 0.05000)
# Ending point: t = 4.48, x = 95.65%  Checking the solution: (5.2917325816560683e-13, 2.7063878448701265e-13)
# tuniv = 711.16  Checking the solution:  -1.05832009822e-11
# Fold-change in tumor size: 1.17
# * Parameters: T = 4.0, Tbar = 22.0 (μ = 0.25000, μbar = 0.04545)
# Ending point: t = 4.51, x = 96.01%  Checking the solution: (-1.1133878914994695e-13, -5.9052395657385803e-14)
# tuniv = 710.88  Checking the solution:  -1.62138358295e-12
# Fold-change in tumor size: 1.27
# * Parameters: T = 4.0, Tbar = 24.0 (μ = 0.25000, μbar = 0.04167)
# Ending point: t = 4.55, x = 96.31%  Checking the solution: (-1.4145301013038595e-08, -7.9702552428498085e-07)
# tuniv = 711.76  Checking the solution:  -6.39210906428e-14
# Fold-change in tumor size: 1.37
# * Parameters: T = 4.0, Tbar = 26.0 (μ = 0.25000, μbar = 0.03846)
# Ending point: t = 4.57, x = 96.57%  Checking the solution: (-5.7014018999755287e-09, -2.552844806461154e-11)
# tuniv = 710.37  Checking the solution:  7.58222651331e-11
# Fold-change in tumor size: 1.44
# * Parameters: T = 4.0, Tbar = 28.0 (μ = 0.25000, μbar = 0.03571)
# Ending point: t = 4.60, x = 96.80%  Checking the solution: (5.3283288611731218e-13, 5.6857106577335692e-13)
# tuniv = 710.14  Checking the solution:  -2.18880469305e-13
# Fold-change in tumor size: 1.51
# * Parameters: T = 4.0, Tbar = 30.0 (μ = 0.25000, μbar = 0.03333)
# Ending point: t = 4.62, x = 96.99%  Checking the solution: (-6.1041291975216025e-09, -5.0870745749812922e-08)
# tuniv = 710.00  Checking the solution:  5.41511280261e-14
# Fold-change in tumor size: 1.58
# * Parameters: T = 4.0, Tbar = 32.0 (μ = 0.25000, μbar = 0.03125)
# Ending point: t = 4.64, x = 97.17%  Checking the solution: (-4.7841187002223675e-14, -2.5052905267651978e-14)
# tuniv = 709.72  Checking the solution:  -1.24170812521e-12
# Fold-change in tumor size: 1.65
# * Parameters: T = 4.0, Tbar = 34.0 (μ = 0.25000, μbar = 0.02941)
# Ending point: t = 4.65, x = 97.32%  Checking the solution: (-4.2582582266635752e-14, -1.9000467791096012e-14)
# tuniv = 709.53  Checking the solution:  -9.66518531875e-14
# Fold-change in tumor size: 1.71
# * Parameters: T = 4.0, Tbar = 36.0 (μ = 0.25000, μbar = 0.02778)
# Ending point: t = 4.67, x = 97.46%  Checking the solution: (-4.430381325818105e-12, 5.2954398371218575e-13)
# tuniv = 709.34  Checking the solution:  -4.42978986825e-14
# Fold-change in tumor size: 1.76
# * Parameters: T = 4.0, Tbar = 38.0 (μ = 0.25000, μbar = 0.02632)
# Ending point: t = 4.68, x = 97.59%  Checking the solution: (-1.2715142141723836e-13, -5.9082814133891125e-14)
# tuniv = 709.17  Checking the solution:  -2.81302758864e-14
# Fold-change in tumor size: 1.81
# * Parameters: T = 4.0, Tbar = 40.0 (μ = 0.25000, μbar = 0.02500)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.69, x = 97.70%  Checking the solution: (-8.7233418863530613e-10, -3.1908811627744641e-10)
# tuniv = 709.00  Checking the solution:  2.15660822533e-13
# Fold-change in tumor size: 1.86
# * Parameters: T = 4.0, Tbar = 42.0 (μ = 0.25000, μbar = 0.02381)
# Ending point: t = 4.71, x = 97.80%  Checking the solution: (-5.3589783059863788e-09, -7.6215362849451902e-10)
# tuniv = 708.84  Checking the solution:  3.59989815735e-14
# Fold-change in tumor size: 1.90
# * Parameters: T = 4.0, Tbar = 44.0 (μ = 0.25000, μbar = 0.02273)
# Ending point: t = 4.72, x = 97.90%  Checking the solution: (-2.0421233389888729e-08, -4.7316309298641934e-09)
# tuniv = 708.70  Checking the solution:  -3.33233440841e-13
# Fold-change in tumor size: 1.94
# * Parameters: T = 4.0, Tbar = 46.0 (μ = 0.25000, μbar = 0.02174)
# Ending point: t = 4.73, x = 97.98%  Checking the solution: (-1.7345358058409886e-08, -3.4431806587826053e-09)
# tuniv = 708.55  Checking the solution:  -3.26128013484e-14
# Fold-change in tumor size: 1.98
# * Parameters: T = 4.0, Tbar = 48.0 (μ = 0.25000, μbar = 0.02083)
# Ending point: t = 4.74, x = 98.06%  Checking the solution: (-8.8436951967216302e-09, -2.3289908564427263e-08)
# tuniv = 708.45  Checking the solution:  -5.35682609382e-14
# Fold-change in tumor size: 2.01
# * Parameters: T = 4.0, Tbar = 50.0 (μ = 0.25000, μbar = 0.02000)
# Ending point: t = 4.74, x = 98.14%  Checking the solution: (-1.4354705614219047e-09, -1.4973697894690037e-10)
# tuniv = 708.26  Checking the solution:  -7.93982934955e-14
# Fold-change in tumor size: 2.05
# * Parameters: T = 4.0, Tbar = 52.0 (μ = 0.25000, μbar = 0.01923)
# Ending point: t = 4.75, x = 98.21%  Checking the solution: (-2.5338745126179018e-09, 2.8919061395466401e-12)
# tuniv = 708.13  Checking the solution:  1.48492329544e-15
# Fold-change in tumor size: 2.08
# * Parameters: T = 4.0, Tbar = 54.0 (μ = 0.25000, μbar = 0.01852)
# Ending point: t = 4.76, x = 98.27%  Checking the solution: (-3.9608761061109325e-09, 1.0643250223658552e-11)
# tuniv = 708.00  Checking the solution:  1.93456362041e-14
# Fold-change in tumor size: 2.11
# * Parameters: T = 4.0, Tbar = 56.0 (μ = 0.25000, μbar = 0.01786)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.77, x = 98.33%  Checking the solution: (-4.7014414416695496e-09, -3.8415839290126456e-11)
# tuniv = 707.88  Checking the solution:  -3.85802501057e-14
# Fold-change in tumor size: 2.14
# * Parameters: T = 4.0, Tbar = 58.0 (μ = 0.25000, μbar = 0.01724)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.77, x = 98.38%  Checking the solution: (-7.0885178802538571e-09, -6.9641937192505303e-08)
# tuniv = 707.96  Checking the solution:  -6.25438034696e-11
# Fold-change in tumor size: 2.16
# * Parameters: T = 4.0, Tbar = 60.0 (μ = 0.25000, μbar = 0.01667)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.78, x = 98.43%  Checking the solution: (-5.5940764568361042e-09, -8.7383162296653505e-08)
# tuniv = 707.90  Checking the solution:  1.27226007507e-11
# Fold-change in tumor size: 2.19
# * Parameters: T = 4.0, Tbar = 62.0 (μ = 0.25000, μbar = 0.01613)
# Ending point: t = 4.78, x = 98.48%  Checking the solution: (-1.0317129676752872e-08, -4.0942172296210795e-08)
# tuniv = 707.65  Checking the solution:  -3.52523565894e-13
# Fold-change in tumor size: 2.21
# * Parameters: T = 4.0, Tbar = 64.0 (μ = 0.25000, μbar = 0.01562)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 4.79, x = 98.53%  Checking the solution: (-1.238990616477501e-08, -7.9044304000771006e-10)
# tuniv = 707.43  Checking the solution:  -3.33288951992e-13
# Fold-change in tumor size: 2.23
# * Parameters: T = 4.0, Tbar = 66.0 (μ = 0.25000, μbar = 0.01515)
# Ending point: t = 4.79, x = 98.57%  Checking the solution: (-1.3901436663867108e-08, -3.3783727121503007e-09)
# tuniv = 707.33  Checking the solution:  1.06581410364e-13
# Fold-change in tumor size: 2.26
# * Parameters: T = 4.0, Tbar = 68.0 (μ = 0.25000, μbar = 0.01471)
# Ending point: t = 4.80, x = 98.61%  Checking the solution: (-2.9271823761698552e-09, -1.0110675094106567e-07)
# tuniv = 707.56  Checking the solution:  -1.17322818127e-13
# Fold-change in tumor size: 2.28
# * Parameters: T = 4.0, Tbar = 70.0 (μ = 0.25000, μbar = 0.01429)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.80, x = 98.65%  Checking the solution: (-1.7255257582451232e-09, 1.2752595940844806e-10)
# tuniv = 707.12  Checking the solution:  -5.29295218765e-11
# Fold-change in tumor size: 2.30
# * Parameters: T = 4.0, Tbar = 72.0 (μ = 0.25000, μbar = 0.01389)
# Ending point: t = 4.81, x = 98.69%  Checking the solution: (-3.902894899701884e-09, 2.168488634675428e-09)
# tuniv = 707.02  Checking the solution:  1.37251321419e-13
# Fold-change in tumor size: 2.31
# * Parameters: T = 4.0, Tbar = 74.0 (μ = 0.25000, μbar = 0.01351)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 4.81, x = 98.72%  Checking the solution: (1.957072307409398e-13, 9.0751237588092412e-14)
# tuniv = 706.93  Checking the solution:  -4.12864187282e-15
# Fold-change in tumor size: 2.33
# * Parameters: T = 4.0, Tbar = 76.0 (μ = 0.25000, μbar = 0.01316)
# Ending point: t = 4.81, x = 98.75%  Checking the solution: (5.8706803270546318e-13, 2.9484991269101011e-13)
# tuniv = 706.84  Checking the solution:  -2.671474153e-15
# Fold-change in tumor size: 2.35
# * Parameters: T = 4.0, Tbar = 78.0 (μ = 0.25000, μbar = 0.01282)
# Ending point: t = 4.82, x = 98.78%  Checking the solution: (2.1695317191885886e-14, 4.172532146513957e-14)
# tuniv = 706.75  Checking the solution:  1.54112833606e-14
# Fold-change in tumor size: 2.37
# * Parameters: T = 4.0, Tbar = 80.0 (μ = 0.25000, μbar = 0.01250)
# Ending point: t = 4.82, x = 98.81%  Checking the solution: (1.2671665205904271e-12, -1.9086622332402849e-12)
# tuniv = 706.66  Checking the solution:  7.55645546135e-15
# Fold-change in tumor size: 2.38
# * Parameters: T = 4.0, Tbar = 82.0 (μ = 0.25000, μbar = 0.01220)
# Ending point: t = 4.82, x = 98.84%  Checking the solution: (-5.9888552521141703e-12, -3.7428581780703371e-13)
# tuniv = 706.57  Checking the solution:  5.10980147084e-14
# Fold-change in tumor size: 2.40
# * Parameters: T = 4.0, Tbar = 84.0 (μ = 0.25000, μbar = 0.01190)
# Ending point: t = 4.83, x = 98.87%  Checking the solution: (5.0427071271116636e-13, -3.5096209122600512e-13)
# tuniv = 706.49  Checking the solution:  -5.41233724505e-15
# Fold-change in tumor size: 2.41
# * Parameters: T = 4.0, Tbar = 86.0 (μ = 0.25000, μbar = 0.01163)
# Ending point: t = 4.83, x = 98.89%  Checking the solution: (-2.3842044819778958e-12, -9.9262965976070435e-14)
# tuniv = 706.41  Checking the solution:  4.82947015712e-15
# Fold-change in tumor size: 2.42
# * Parameters: T = 4.0, Tbar = 88.0 (μ = 0.25000, μbar = 0.01136)
# Ending point: t = 4.83, x = 98.92%  Checking the solution: (-2.4851372585107822e-14, -1.5730219948943267e-13)
# tuniv = 706.33  Checking the solution:  -9.43689570931e-16
# Fold-change in tumor size: 2.44
# * Parameters: T = 4.0, Tbar = 90.0 (μ = 0.25000, μbar = 0.01111)
# Ending point: t = 4.84, x = 98.94%  Checking the solution: (-3.5330292483632506e-14, -8.9298562221813678e-15)
# tuniv = 706.25  Checking the solution:  -1.30451205393e-14
# Fold-change in tumor size: 2.45
# * Parameters: T = 4.0, Tbar = 92.0 (μ = 0.25000, μbar = 0.01087)
# Ending point: t = 4.84, x = 98.96%  Checking the solution: (1.3834775032376692e-13, 4.5025582908826642e-14)
# tuniv = 706.17  Checking the solution:  7.57184870359e-11
# Fold-change in tumor size: 2.46
# * Parameters: T = 4.0, Tbar = 94.0 (μ = 0.25000, μbar = 0.01064)
# Ending point: t = 4.84, x = 98.99%  Checking the solution: (3.3131600462274809e-14, -3.4959935610034117e-13)
# tuniv = 706.10  Checking the solution:  6.81806000546e-11
# Fold-change in tumor size: 2.48
# * Parameters: T = 4.0, Tbar = 96.0 (μ = 0.25000, μbar = 0.01042)
# Ending point: t = 4.84, x = 99.01%  Checking the solution: (-1.1614643455026831e-13, -2.236617313548022e-13)
# tuniv = 706.02  Checking the solution:  6.17515205636e-11
# Fold-change in tumor size: 2.49
# * Parameters: T = 4.0, Tbar = 98.0 (μ = 0.25000, μbar = 0.01020)
# Ending point: t = 4.85, x = 99.03%  Checking the solution: (-1.2258286397824596e-09, -1.1154484124425941e-07)
# tuniv = 706.51  Checking the solution:  -7.16207093632e-11
# Fold-change in tumor size: 2.50
# * Parameters: T = 4.0, Tbar = 100.0 (μ = 0.25000, μbar = 0.01000)
# Ending point: t = 4.85, x = 99.04%  Checking the solution: (-2.7384052915883338e-09, -2.0155905850176563e-10)
# tuniv = 705.88  Checking the solution:  -7.67996777284e-14
# Fold-change in tumor size: 2.51
# * Parameters: T = 4.0, Tbar = 102.0 (μ = 0.25000, μbar = 0.00980)
# Ending point: t = 4.85, x = 99.06%  Checking the solution: (-1.6744803088494014e-09, -4.8484949654466545e-10)
# tuniv = 705.81  Checking the solution:  4.17833823096e-11
# Fold-change in tumor size: 2.52
# * Parameters: T = 4.0, Tbar = 104.0 (μ = 0.25000, μbar = 0.00962)
# Ending point: t = 4.85, x = 99.08%  Checking the solution: (-3.7301633744702517e-09, -4.4523616028945517e-09)
# tuniv = 705.76  Checking the solution:  8.76529404614e-12
# Fold-change in tumor size: 2.53
# * Parameters: T = 4.0, Tbar = 106.0 (μ = 0.25000, μbar = 0.00943)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.86, x = 99.10%  Checking the solution: (-8.4571128276425269e-09, -3.8998033820659653e-09)
# tuniv = 705.70  Checking the solution:  4.49591752716e-11
# Fold-change in tumor size: 2.54
# * Parameters: T = 4.0, Tbar = 108.0 (μ = 0.25000, μbar = 0.00926)
# Ending point: t = 4.86, x = 99.11%  Checking the solution: (-5.8794326554802592e-09, -3.7557063356024108e-08)
# tuniv = 705.80  Checking the solution:  -8.24340595784e-15
# Fold-change in tumor size: 2.55
# * Parameters: T = 4.0, Tbar = 110.0 (μ = 0.25000, μbar = 0.00909)
# Ending point: t = 4.86, x = 99.13%  Checking the solution: (-4.1116312938093941e-09, -7.154224336739726e-08)
# tuniv = 705.93  Checking the solution:  -7.44404538011e-14
# Fold-change in tumor size: 2.56
# * Parameters: T = 4.0, Tbar = 112.0 (μ = 0.25000, μbar = 0.00893)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.86, x = 99.14%  Checking the solution: (-4.4198672217432232e-09, -3.9138442104812365e-08)
# tuniv = 705.69  Checking the solution:  -4.54580817433e-13
# Fold-change in tumor size: 2.56
# * Parameters: T = 4.0, Tbar = 114.0 (μ = 0.25000, μbar = 0.00877)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.87, x = 99.16%  Checking the solution: (-5.1630767380832177e-09, -9.180936977206811e-08)
# tuniv = 705.95  Checking the solution:  -4.88054041625e-13
# Fold-change in tumor size: 2.57
# * Parameters: T = 4.0, Tbar = 116.0 (μ = 0.25000, μbar = 0.00862)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.86, x = 99.17%  Checking the solution: (-1.7325219533087946e-08, -5.6567828141680017e-09)
# tuniv = 705.39  Checking the solution:  3.6325109587e-14
# Fold-change in tumor size: 2.58
# * Parameters: T = 4.0, Tbar = 118.0 (μ = 0.25000, μbar = 0.00847)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.87, x = 99.19%  Checking the solution: (-3.6853770155959286e-09, -1.8640030822721053e-07)
# tuniv = 706.48  Checking the solution:  -5.49192635813e-13
# Fold-change in tumor size: 2.59
# * Parameters: T = 4.0, Tbar = 120.0 (μ = 0.25000, μbar = 0.00833)
# Ending point: t = 4.87, x = 99.20%  Checking the solution: (-5.6576770412850241e-09, -4.8090138416046517e-10)
# tuniv = 705.24  Checking the solution:  1.47105244652e-11
# Fold-change in tumor size: 2.60
