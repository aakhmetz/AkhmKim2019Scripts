# %% [markdown]
# # Aim of this notebook
#
# * To construct the singular curve of universal type to finalize the solution of the optimal control problem

# %% [markdown]
# # Preamble

# %%
from sympy import *
init_printing(use_latex='mathjax')

# Plotting
# %matplotlib inline
## Make inline plots raster graphics
from IPython.display import set_matplotlib_formats
## Import modules for plotting and data analysis
import matplotlib.pyplot as plt
from matplotlib import gridspec,rc,colors
import matplotlib.ticker as plticker
## Parameters for seaborn plots
import seaborn as sns
sns.set(style='white',font_scale=1.25,
        rc={"xtick.major.size": 6, "ytick.major.size": 6,
            'text.usetex': False, 'font.family': 'serif', 'font.serif': ['Times']})

import pandas as pd
pd.set_option('mode.chained_assignment',None)

import numpy as np
from scipy.optimize import fsolve, root
from scipy.integrate import ode
backend = 'dopri5'
import warnings

# Timer
import time

from copy import deepcopy

from itertools import cycle
palette_size = 10;
clrs = sns.color_palette("Reds",palette_size)
iclrs = cycle(clrs) # iterated colors

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter values

# %% [markdown]
# * Birth rate and const of downregulation are defined below in order to fit some experim. data

# %%
d = .13 # death rate
α = .3 # low equilibrium point at expression of the main pathway (high equilibrium is at one)
θ = .45 # threshold value for the expression of the main pathway
κ = 40 # robustness parameter

# %% [markdown]
# * Symbolic variables - the list insludes μ & μbar, because they will be varied later

# %%
σ, φ0, φ, x, μ, μbar = symbols('sigma, phi0, phi, x, mu, mubar')

# %% [markdown]
# * Main functions

# %%
A = 1-σ*(1-θ)
Eminus = (α*A-θ)**2/2
ΔE = A*(1-α)*((1+α)*A/2-θ)
ΔEf = lambdify(σ,ΔE)

# %% [markdown]
# * Birth rate and cost of downregulation

# %%
b = (0.1*(exp(κ*(ΔEf(1)))+1)-0.14*(exp(κ*ΔEf(0))+1))/(exp(κ*ΔEf(1))-exp(κ*ΔEf(0))) # birth rate
χ = 1-(0.14*(exp(κ*ΔEf(0))+1)-b*exp(κ*ΔEf(0)))/b
b, χ
# Out:
# (0.140168330860362, 0.325961223954473)

# %%
c_relative = 0.2
c = c_relative*(b-d)/b+(1-c_relative)*χ/(exp(κ*ΔEf(0))+1) # cost of resistance
c
# Out:
# 0.0154694776420055

# %% [markdown]
# * Hamiltonian *H* and a part of it ρ that includes the control variable σ

# %%
h = b*(χ/(exp(κ*ΔE)+1)*(1-x)+c*x)
H = -φ0 + φ*(b*(χ/(exp(κ*ΔE)+1)-c)*x*(1-x)+μ*(1-x)/(exp(κ*ΔE)+1)-μbar*exp(-κ*Eminus)*x) + h
ρ = (φ*(b*χ*x+μ)+b*χ)/(exp(κ*ΔE)+1)*(1-x)-φ*μbar*exp(-κ*Eminus)*x
H, ρ
# Out:
# ⎛  ⎛                                                                        2
# ⎜  ⎜                μ⋅(-x + 1)                         -20⋅(-0.165⋅σ - 0.15)
# ⎜φ⋅⎜────────────────────────────────────────── - μ̅⋅x⋅ℯ
# ⎜  ⎜ 40⋅(-0.385⋅σ + 0.7)⋅(-0.3575⋅σ + 0.2)
# ⎝  ⎝ℯ                                      + 1
#
#
#     ⎛                                   0.045689440686899             ⎞
# + x⋅⎜-0.00216833086036159 + ──────────────────────────────────────────⎟⋅(-x +
#     ⎜                        40⋅(-0.385⋅σ + 0.7)⋅(-0.3575⋅σ + 0.2)    ⎟
#     ⎝                       ℯ                                      + 1⎠
#
#   ⎞
#   ⎟                                        0.045689440686899⋅(-x + 1)
# 1)⎟ - φ₀ + 0.00216833086036159⋅x + ──────────────────────────────────────────,
#   ⎟                                 40⋅(-0.385⋅σ + 0.7)⋅(-0.3575⋅σ + 0.2)
#   ⎠                                ℯ                                      + 1
#
#                                 2
#            -20⋅(-0.165⋅σ - 0.15)    (-x + 1)⋅(φ⋅(μ + 0.045689440686899⋅x) + 0.
#  - μ̅⋅φ⋅x⋅ℯ                       + ──────────────────────────────────────────
#                                              40⋅(-0.385⋅σ + 0.7)⋅(-0.3575⋅σ +
#                                             ℯ
#
#                 ⎞
# 045689440686899)⎟
# ────────────────⎟
# 0.2)            ⎟
#      + 1        ⎠

# %% [markdown]
# * Same but for no treatment (σ = 0)

# %%
h0 = h.subs(σ,0)
H0 = H.subs(σ,0)
ρ0 = ρ.subs(σ,0)
H0, ρ0
# Out:
# (φ⋅(0.00368423989943599⋅μ⋅(-x + 1) - 0.637628151621773⋅μ̅⋅x - 0.002⋅x⋅(-x + 1)
# ) - φ₀ + 0.002⋅x + 0.000168330860361587, -0.637628151621773⋅μ̅⋅φ⋅x + 0.0036842
# 3989943599⋅(-x + 1)⋅(φ⋅(μ + 0.045689440686899⋅x) + 0.045689440686899))

# %% [markdown]
# * Machinery: definition of the Poisson brackets

# %%
PoissonBrackets = lambda H1, H2: diff(H1,x)*diff(H2,φ)-diff(H1,φ)*diff(H2,x)

# %% [markdown]
# * Necessary functions and defining the right hand side of dynamical equations

# %%
ρf = lambdify((x,φ,σ,μ,μbar),ρ)
ρ0f = lambdify((x,φ,μ,μbar),ρ0)
dxdτ = lambdify((x,φ,σ,μ,μbar),-diff(H,φ))
dφdτ = lambdify((x,φ,σ,μ,μbar),diff(H,x))
dVdτ = lambdify((x,σ),h)
dρdσ = lambdify((σ,x,φ,μ,μbar),diff(ρ,σ))
dδρdτ = lambdify((x,φ,σ,μ,μbar),-PoissonBrackets(ρ0-ρ,H))
def ode_rhs(t,state,μ,μbar):
    x, φ, V, δρ = state
    σs = [0,1]
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σstar = 1.;
    if ρf(x,φ,σstar,μ,μbar) < ρ0f(x,φ,μ,μbar):
        sgm = 0
    else:
        sgm = σstar
    return [dxdτ(x,φ,sgm,μ,μbar),dφdτ(x,φ,sgm,μ,μbar),dVdτ(x,sgm),dδρdτ(x,φ,σstar,μ,μbar)]

# %%
def get_primary_field(name, experiment,μ,μbar):
    solutions = {}
    solver = ode(ode_rhs).set_integrator(backend)
    τ0 = experiment['τ0']
    tms = np.linspace(τ0,experiment['T_end'],1e3+1)
    for x0 in experiment['x0']:
        δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
        solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
        sol = []; k = 0;
        while (solver.t < experiment['T_end']) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
            solver.integrate(tms[k])
            sol.append([solver.t]+list(solver.y))
            k += 1
        solutions[x0] = {'solution': sol}
    for x0, entry in solutions.items():
        entry['τ'] = [entry['solution'][j][0] for j in range(len(entry['solution']))]
        entry['x'] = [entry['solution'][j][1] for j in range(len(entry['solution']))]
        entry['φ'] = [entry['solution'][j][2] for j in range(len(entry['solution']))]
        entry['V'] = [entry['solution'][j][3] for j in range(len(entry['solution']))]
        entry['δρ'] = [entry['solution'][j][4] for j in range(len(entry['solution']))]
    return solutions
def get_δρ_value(tme,x0,μ,μbar):
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    while (solver.t < tme) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tme)
        sol = [solver.t]+list(solver.y)
    return solver.y[3]
def get_δρ_ending(params,μ,μbar):
    tme, x0 = params
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    _k = 0; sol = []
    while (_k<len(tms)):# and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append(solver.y)
        _k += 1
    #print(sol)
    return(sol[0][3],(sol[1][3]-sol[0][3])/δτ)
def get_state(tme,x0,μ,μbar):
    solver = ode(ode_rhs).set_integrator(backend)
    δρ0 = ρ0.subs(x,x0).subs(φ,0)-ρ.subs(x,x0).subs(φ,0).subs(σ,1.)
    solver.set_initial_value([x0,0,0,δρ0],0.).set_f_params(μ,μbar)
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    _k = 0; sol = []
    while (solver.t < tms[-1]) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append(solver.y)
        _k += 1
    return(list(sol[0])+[(sol[1][3]-sol[0][3])/δτ])

# %% [markdown]
# # Machinery for the universal line

# %% [markdown]
# * To find the universal singular curve we need to define two parameters

# %%
γ0 = PoissonBrackets(PoissonBrackets(H,H0),H)
γ1 = PoissonBrackets(PoissonBrackets(H0,H),H0)

# %% [markdown]
# * The dynamics

# %%
dxdτSingExpr = -(γ0*diff(H0,φ)+γ1*diff(H,φ))/(γ0+γ1)
dφdτSingExpr = (γ0*diff(H0,x)+γ1*diff(H,x))/(γ0+γ1)
dVdτSingExpr = (γ0*h0+γ1*h)/(γ0+γ1)
σSingExpr = γ1*σ/(γ0+γ1)

# %% [markdown]
# * Machinery for Python: lambdify the functions above

# %%
dxdτSing = lambdify((x,φ,σ,μ,μbar),dxdτSingExpr)
dφdτSing = lambdify((x,φ,σ,μ,μbar),dφdτSingExpr)
dVdτSing = lambdify((x,φ,σ,μ,μbar),dVdτSingExpr)
σSing = lambdify((x,φ,σ,μ,μbar),σSingExpr)

# %%
def ode_rhs_Sing(t,state,μ,μbar):
    x, φ, V = state
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σstar = 1.;
    #print([σstar,σSing(x,φ,σstar,μ,μbar)])
    return [dxdτSing(x,φ,σstar,μ,μbar),dφdτSing(x,φ,σstar,μ,μbar),dVdτSing(x,φ,σstar,μ,μbar)]
# def ode_rhs_Sing(t,state,μ,μbar):
#     x, φ, V = state
#     if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
#         σstar = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
#     else:
#         σstar = 1.;
#     σTrav = fsolve(lambda σ: dxdτ(x,φ,σ,μ,μbar)-dxdτSing(x,φ,σstar,μ,μbar),.6)[0]
#     print([σstar,σTrav])
#     return [dxdτSing(x,φ,σstar,μ,μbar),dφdτSing(x,φ,σstar,μ,μbar),dVdτ(x,σTrav)]
def get_universal_curve(end_point,tmax,Nsteps,μ,μbar):
    tms =  np.linspace(end_point[0],tmax,Nsteps);
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    _k = 0; sol = []
    while (solver.t < tms[-1]):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_σ_universal(tme,end_point,μ,μbar):
    δτ = 1.0e-8; tms = [tme,tme+δτ]
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    _k = 0; sol = []
    while (solver.t < tme+δτ):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    x, φ = sol[0][:2]
    sgm = fsolve(lambda σ: dxdτ(x,φ,σ,μ,μbar)-(sol[1][0]-sol[0][0])/δτ,θ/2)[0]
    return sgm
def get_state_universal(tme,end_point,μ,μbar):
    solver = ode(ode_rhs_Sing).set_integrator(backend)
    solver.set_initial_value(end_point[1:4],end_point[0]).set_f_params(μ,μbar)
    solver.integrate(tme)
    return [solver.t]+list(solver.y)

# %%
def ode_rhs_with_σstar(t,state,μ,μbar):
    x, φ, V = state
    if (dρdσ(1.,x,φ,μ,μbar)<0) and (dρdσ(θ,x,φ,μ,μbar)>0):
        σ = fsolve(dρdσ,.8,args=(x,φ,μ,μbar,))[0]
    else:
        σ = 1.;
    return [dxdτ(x,φ,σ,μ,μbar),dφdτ(x,φ,σ,μ,μbar),dVdτ(x,σ)]
def ode_rhs_with_given_σ(t,state,σ,μ,μbar):
    x, φ, V = state
    return [dxdτ(x,φ,σ,μ,μbar),dφdτ(x,φ,σ,μ,μbar),dVdτ(x,σ)]
def get_trajectory_with_σstar(starting_point,tmax,Nsteps,μ,μbar):
    tms = np.linspace(starting_point[0],tmax,Nsteps)
    solver = ode(ode_rhs_with_σstar).set_integrator(backend)
    solver.set_initial_value(starting_point[1:],starting_point[0]).set_f_params(μ,μbar)
    sol = []; _k = 0;
    while solver.t < max(tms) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_trajectory_with_given_σ(starting_point,tmax,Nsteps,σ,μ,μbar):
    tms = np.linspace(starting_point[0],tmax,100)
    solver = ode(ode_rhs_with_given_σ).set_integrator(backend)
    solver.set_initial_value(starting_point[1:],starting_point[0]).set_f_params(σ,μ,μbar)
    sol = []; _k = 0;
    while solver.t < max(tms) and (solver.y[0]<=1.) and (solver.y[0]>=0.):
        solver.integrate(tms[_k])
        sol.append([solver.t]+list(solver.y))
        _k += 1
    return sol
def get_state_with_σstar(tme,starting_point,μ,μbar):
    solver = ode(ode_rhs_with_σstar).set_integrator(backend)
    solver.set_initial_value(starting_point[1:4],starting_point[0]).set_f_params(μ,μbar)
    solver.integrate(tme)
    return [solver.t]+list(solver.y)
def get_finalizing_point_from_universal_curve(tme,tmx,end_point,μ,μbar):
    unv_point = get_state_universal(tme,end_point,μ,μbar)
    return get_state_with_σstar(tmx,unv_point,μ,μbar)[1]

# %% [markdown]
# # Field of optimal trajectories as the solution of the Bellman equation
#
# * μ & μbar are varied by *T* and *T*bar ($\mu=1/T$ and $\bar\mu=1/\bar{T}$)

# %%
tmx = 180.
end_switching_curve = {'t': 24., 'x': .9/.8} 
# for Τ, Τbar in zip([28]*5,[14,21,28,35,60]):
for Τ, Τbar in zip([28],[60]):
    μ = 1./Τ; μbar = 1./Τbar
    print("Parameters: μ = %.5f, μbar = %.5f"%(μ,μbar))
    end_switching_curve['t'], end_switching_curve['x'] = root(get_δρ_ending,(end_switching_curve['t'],end_switching_curve['x']),args=(μ,μbar)).x
    end_point = [end_switching_curve['t']]+get_state(end_switching_curve['t'],end_switching_curve['x'],μ,μbar)
    print("Ending point for the switching line: τ = %.1f days, x = %.1f%%" % (end_point[0], end_point[1]*100))
    print("Checking the solution - should give zero values: ")
    print(get_δρ_ending([end_switching_curve['t'],end_switching_curve['x']],μ,μbar))
    print("* Constructing the primary field")
    experiments = {
        'sol1': { 'T_end': tmx, 'τ0': 0., 'x0': list(np.linspace(0,end_switching_curve['x']-(1e-3),10))+list(np.linspace(end_switching_curve['x']+(1e-6),1.,10)) } }
    primary_field = []
    for name, values in experiments.items():
        primary_field.append(get_primary_field(name,values,μ,μbar))
    print("* Constructing the switching curve")
    switching_curve = []
    x0s = np.linspace(end_switching_curve['x'],1,21); _y = end_switching_curve['t']
    
    for x0 in x0s:
        tme = fsolve(get_δρ_value,_y,args=(x0,μ,μbar))[0]
        if (tme>0):
            switching_curve = switching_curve+[[tme,get_state(tme,x0,μ,μbar)[0]]]
            _y = tme
    print("* Constructing the universal curve")
    universal_curve = get_universal_curve(end_point,tmx,25,μ,μbar)
    print("* Finding the last characteristic")
    #time0 = time.time()
#     tuniv = fsolve(get_finalizing_point_from_universal_curve,tmx-40.,args=(tmx,end_point,μ,μbar,))[0]
    tuniv = root(get_finalizing_point_from_universal_curve,tmx-40,args=(tmx,end_point,μ,μbar)).x
    print(tuniv)
    #print("The proccess to find the last characteristic took %0.1f minutes" % ((time.time()-time0)/60.))
    univ_point = get_state_universal(tuniv,end_point,μ,μbar)
    print("The last point on the universal line:")
    print(univ_point)
    last_trajectory = get_trajectory_with_σstar(univ_point,tmx,50,μ,μbar)
    print("Final state:")
    final_state = get_state_with_σstar(tmx,univ_point,μ,μbar)
    print(final_state)
    print("Fold-change in tumor size: %.2f"%(exp((b-d)*tmx-final_state[-1])))
    # Plotting
    plt.rcParams['figure.figsize'] = (6.75, 4)
    _k = 0
    for solutions in primary_field:
        for x0, entry in solutions.items():
            plt.plot(entry['τ'], entry['x'], 'k-', linewidth=.9, color=clrs[_k%palette_size])
            _k += 1
    plt.plot([x[0] for x in switching_curve],[x[1] for x in switching_curve],linewidth=2,color="red")
    plt.plot([end_point[0]],[end_point[1]],marker='o',color="red")
    plt.plot([x[0] for x in universal_curve],[x[1] for x in universal_curve],linewidth=2,color="red")
    plt.plot([x[0] for x in last_trajectory],[x[1] for x in last_trajectory],linewidth=.9,color="black")
    plt.xlim([0,tmx]); plt.ylim([0,1]);
    plt.xlabel("time, days"); plt.ylabel("fraction of resistant cells")
    plt.show()
    print()
# Out:
# Parameters: μ = 0.03571, μbar = 0.01667
# Ending point for the switching line: τ = 25.5 days, x = 71.6%
# Checking the solution - should give zero values:
# (-4.204122433017251e-08, -9.106111013088652e-08)
# * Constructing the primary field
# * Constructing the switching curve
# * Constructing the universal curve
# * Finding the last characteristic
# [149.95741812]
# The last point on the universal line:
# [149.95741811739222, 0.7158075555993243, -0.4989833791879546, 0.904905603294865]
# Final state:
# [180.0, 1.205036070928145e-12, -1.1012177672839152, 1.6210541658554904]
# Fold-change in tumor size: 1.23

# %%
import csv
from numpy.linalg import norm
File = open("../figures/draft/sensitivity_mu-high_cost.csv", 'w')
File.write("T,Tbar,mu,mubar,sw_start_x,sw_end_t,sw_end_x,univ_point_t,univ_point_x,outcome,err_sw_t,err_sw_x\n")
writer = csv.writer(File,lineterminator='\n')

end_switching_curve0 = {'t': 40.36, 'x': .92}
end_switching_curve_prev_t = end_switching_curve0['t']
tuniv = tmx-30.
Ts = np.arange(40,3,-1) #Τbars; 
Τbars = np.arange(40,3,-1) #np.arange(120,1,-1) #need to change here if more
for Τ in Ts:
    μ = 1./Τ
    end_switching_curve = deepcopy(end_switching_curve0)
    for Τbar in Τbars:
        μbar = 1./Τbar
        print("* Parameters: T = %.1f, Tbar = %.1f (μ = %.5f, μbar = %.5f)"%(Τ,Τbar,μ,μbar))
        success = False; err = 1.
        while (not success)|(norm(err)>1e-6):
            end_switching_curve = {'t': 2*end_switching_curve['t']-end_switching_curve_prev_t-.001, 
                                   'x': end_switching_curve['x']-0.002} 
            sol = root(get_δρ_ending,(end_switching_curve['t'],end_switching_curve['x']),args=(μ,μbar))
            end_switching_curve_prev_t = end_switching_curve['t']
            end_switching_curve_prev_x = end_switching_curve['x']
            end_switching_curve['t'], end_switching_curve['x'] = sol.x 
            success = sol.success
            err = get_δρ_ending([end_switching_curve['t'],end_switching_curve['x']],μ,μbar)
            if (not success): 
                print("! Trying again...", sol.message)
            elif (norm(err)>1e-6):
                print("! Trying again... Convergence is not sufficient")       
        else:
            end_point = [end_switching_curve['t']]+get_state(end_switching_curve['t'],end_switching_curve['x'],μ,μbar)
            print("Ending point: t = %.2f, x = %.2f%%"%(end_switching_curve['t'],100*end_switching_curve['x'])," Checking the solution:",err)
            universal_curve = get_universal_curve(end_point,tmx,25,μ,μbar)
            tuniv = root(get_finalizing_point_from_universal_curve,tuniv,args=(tmx,end_point,μ,μbar)).x
            err_tuniv = get_finalizing_point_from_universal_curve(tuniv,tmx,end_point,μ,μbar)
            univ_point = get_state_universal(tuniv,end_point,μ,μbar)
            print("tuniv = %.2f"%tuniv,"xuniv = %.2f%%"%(100*univ_point[1])," Checking the solution: ",err_tuniv)
            final_state = get_state_with_σstar(tmx,univ_point,μ,μbar)
            outcome = exp((b-d)*tmx-final_state[-1])
            print("Fold-change in tumor size: %.2f"%(outcome))
            output = [Τ,Τbar,μ,μbar,end_switching_curve['x'],end_point[0],end_point[1]]+list(univ_point[0:2])+[outcome]+list(err)+[err_tuniv]
            writer.writerow(output)
        if (Τbar==Τ):
            end_switching_curve0 = deepcopy(end_switching_curve) 

File.close()
# Out:
# * Parameters: T = 40.0, Tbar = 40.0 (μ = 0.02500, μbar = 0.02500)
# Ending point: t = 28.42, x = 85.61%  Checking the solution: (-6.431459309685764e-13, -2.564424486853651e-14)
# tuniv = 148.30 xuniv = 61.46%  Checking the solution:  -8.813713647803922e-13
# Fold-change in tumor size: 0.79
# * Parameters: T = 40.0, Tbar = 39.0 (μ = 0.02500, μbar = 0.02564)
# Ending point: t = 28.31, x = 85.33%  Checking the solution: (2.133514435304388e-13, 5.494313463620051e-14)
# tuniv = 148.49 xuniv = 61.10%  Checking the solution:  5.130570968070458e-11
# Fold-change in tumor size: 0.78
# * Parameters: T = 40.0, Tbar = 38.0 (μ = 0.02500, μbar = 0.02632)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 28.19, x = 85.04%  Checking the solution: (-1.06787083939652e-13, -3.9119905115077993e-14)
# tuniv = 148.69 xuniv = 60.73%  Checking the solution:  -8.631248493706778e-12
# Fold-change in tumor size: 0.76
# * Parameters: T = 40.0, Tbar = 37.0 (μ = 0.02500, μbar = 0.02703)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 28.06, x = 84.74%  Checking the solution: (-1.7419425704972484e-13, -1.0724954019311197e-13)
# tuniv = 148.89 xuniv = 60.34%  Checking the solution:  1.2015458072944796e-11
# Fold-change in tumor size: 0.75
# * Parameters: T = 40.0, Tbar = 36.0 (μ = 0.02500, μbar = 0.02778)
# Ending point: t = 27.94, x = 84.43%  Checking the solution: (3.614629161442654e-14, -1.9361850651576275e-14)
# tuniv = 149.09 xuniv = 59.95%  Checking the solution:  -2.6030566591117577e-13
# Fold-change in tumor size: 0.74
# * Parameters: T = 40.0, Tbar = 35.0 (μ = 0.02500, μbar = 0.02857)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.83, x = 84.10%  Checking the solution: (-5.5296010706484404e-08, -2.8021783247874363e-07)
# tuniv = 149.42 xuniv = 59.42%  Checking the solution:  -1.6514067890938122e-11
# Fold-change in tumor size: 0.73
# * Parameters: T = 40.0, Tbar = 34.0 (μ = 0.02500, μbar = 0.02941)
# Ending point: t = 27.68, x = 83.75%  Checking the solution: (-1.5399133563583665e-07, -1.4808424230451737e-07)
# tuniv = 149.57 xuniv = 59.06%  Checking the solution:  1.609448685435666e-11
# Fold-change in tumor size: 0.71
# * Parameters: T = 40.0, Tbar = 33.0 (μ = 0.02500, μbar = 0.03030)
# Ending point: t = 27.59, x = 83.39%  Checking the solution: (-2.0411188475734256e-07, -7.50566958929909e-07)
# tuniv = 150.04 xuniv = 58.38%  Checking the solution:  1.346089906206771e-12
# Fold-change in tumor size: 0.70
# * Parameters: T = 40.0, Tbar = 32.0 (μ = 0.02500, μbar = 0.03125)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.43, x = 83.01%  Checking the solution: (-2.5916362134243997e-07, -4.905807836820422e-07)
# tuniv = 150.14 xuniv = 58.05%  Checking the solution:  -7.50054601761363e-11
# Fold-change in tumor size: 0.69
# * Parameters: T = 40.0, Tbar = 31.0 (μ = 0.02500, μbar = 0.03226)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.26, x = 82.61%  Checking the solution: (-2.462567007613632e-07, -1.6808105170983405e-07)
# tuniv = 150.23 xuniv = 57.73%  Checking the solution:  1.3811288918086362e-11
# Fold-change in tumor size: 0.67
# * Parameters: T = 40.0, Tbar = 30.0 (μ = 0.02500, μbar = 0.03333)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.13, x = 82.20%  Checking the solution: (-2.2369655902838279e-07, -4.225110455187593e-07)
# tuniv = 150.56 xuniv = 57.16%  Checking the solution:  -3.3759384177045604e-12
# Fold-change in tumor size: 0.66
# * Parameters: T = 40.0, Tbar = 29.0 (μ = 0.02500, μbar = 0.03448)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 26.99, x = 81.76%  Checking the solution: (-1.8230771872240155e-07, -6.473157840647796e-07)
# tuniv = 150.87 xuniv = 56.59%  Checking the solution:  -7.129435930508521e-13
# Fold-change in tumor size: 0.64
# * Parameters: T = 40.0, Tbar = 28.0 (μ = 0.02500, μbar = 0.03571)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 26.79, x = 81.30%  Checking the solution: (-1.0576098189738792e-07, -4.586679438915096e-08)
# tuniv = 150.87 xuniv = 56.32%  Checking the solution:  1.3146192467949902e-11
# Fold-change in tumor size: 0.63
# * Parameters: T = 40.0, Tbar = 27.0 (μ = 0.02500, μbar = 0.03704)
# Ending point: t = 26.62, x = 80.81%  Checking the solution: (9.487289629578864e-13, 1.0795948976426191e-13)
# tuniv = 151.10 xuniv = 55.81%  Checking the solution:  1.2763790024905575e-11
# Fold-change in tumor size: 0.61
# * Parameters: T = 40.0, Tbar = 26.0 (μ = 0.02500, μbar = 0.03846)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 26.45, x = 80.29%  Checking the solution: (1.4916567759755855e-13, 2.4830930537431096e-14)
# tuniv = 151.34 xuniv = 55.27%  Checking the solution:  2.1849605458257315e-12
# Fold-change in tumor size: 0.59
# * Parameters: T = 40.0, Tbar = 25.0 (μ = 0.02500, μbar = 0.04000)
# Ending point: t = 26.28, x = 79.75%  Checking the solution: (-2.0399610625925925e-07, -3.0547025632864664e-09)
# tuniv = 151.60 xuniv = 54.71%  Checking the solution:  -1.8560153414171054e-13
# Fold-change in tumor size: 0.58
# * Parameters: T = 40.0, Tbar = 24.0 (μ = 0.02500, μbar = 0.04167)
# Ending point: t = 26.10, x = 79.16%  Checking the solution: (-2.3053767536168363e-07, 3.0744244019743027e-08)
# tuniv = 151.85 xuniv = 54.14%  Checking the solution:  5.62580537710744e-12
# Fold-change in tumor size: 0.56
# * Parameters: T = 40.0, Tbar = 23.0 (μ = 0.02500, μbar = 0.04348)
# Ending point: t = 25.93, x = 78.55%  Checking the solution: (-1.526729407532731e-08, -3.2150572127237627e-07)
# tuniv = 152.23 xuniv = 53.42%  Checking the solution:  -1.3323231407014191e-12
# Fold-change in tumor size: 0.54
# * Parameters: T = 40.0, Tbar = 22.0 (μ = 0.02500, μbar = 0.04545)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.77, x = 77.89%  Checking the solution: (-1.7618079565285234e-07, -9.380022105586914e-07)
# tuniv = 152.71 xuniv = 52.59%  Checking the solution:  -2.691499800810959e-12
# Fold-change in tumor size: 0.52
# * Parameters: T = 40.0, Tbar = 21.0 (μ = 0.02500, μbar = 0.04762)
# Ending point: t = 25.52, x = 77.19%  Checking the solution: (-2.4027853181578696e-12, -2.1441212140874216e-13)
# tuniv = 152.68 xuniv = 52.23%  Checking the solution:  -2.0248247523113605e-12
# Fold-change in tumor size: 0.50
# * Parameters: T = 40.0, Tbar = 20.0 (μ = 0.02500, μbar = 0.05000)
# Ending point: t = 25.32, x = 76.43%  Checking the solution: (1.84546174288112e-13, -4.940135370797376e-13)
# tuniv = 152.96 xuniv = 51.54%  Checking the solution:  -7.985834216128751e-13
# Fold-change in tumor size: 0.48
# * Parameters: T = 40.0, Tbar = 19.0 (μ = 0.02500, μbar = 0.05263)
# Ending point: t = 25.11, x = 75.62%  Checking the solution: (6.395954390571966e-13, 6.970319422725133e-13)
# tuniv = 153.26 xuniv = 50.82%  Checking the solution:  5.279575387984181e-12
# Fold-change in tumor size: 0.46
# * Parameters: T = 40.0, Tbar = 18.0 (μ = 0.02500, μbar = 0.05556)
# Ending point: t = 24.88, x = 74.75%  Checking the solution: (-2.602862485278929e-13, -2.2840494371861716e-14)
# tuniv = 153.56 xuniv = 50.06%  Checking the solution:  -8.055257849637343e-13
# Fold-change in tumor size: 0.44
# * Parameters: T = 40.0, Tbar = 17.0 (μ = 0.02500, μbar = 0.05882)
# Ending point: t = 24.66, x = 73.81%  Checking the solution: (-5.1392964986572034e-08, -2.3068823204462662e-09)
# tuniv = 153.87 xuniv = 49.26%  Checking the solution:  2.7480240305521875e-12
# Fold-change in tumor size: 0.42
# * Parameters: T = 40.0, Tbar = 16.0 (μ = 0.02500, μbar = 0.06250)
# Ending point: t = 24.44, x = 72.78%  Checking the solution: (-1.6235121161857595e-07, -4.779601912913002e-07)
# tuniv = 154.33 xuniv = 48.30%  Checking the solution:  -1.3728601588880451e-12
# Fold-change in tumor size: 0.39
# * Parameters: T = 40.0, Tbar = 15.0 (μ = 0.02500, μbar = 0.06667)
# Ending point: t = 24.17, x = 71.67%  Checking the solution: (-1.0309909994571285e-07, -1.8127426219572166e-08)
# tuniv = 154.53 xuniv = 47.53%  Checking the solution:  5.409839243242232e-13
# Fold-change in tumor size: 0.37
# * Parameters: T = 40.0, Tbar = 14.0 (μ = 0.02500, μbar = 0.07143)
# Ending point: t = 23.92, x = 70.44%  Checking the solution: (-1.1070795566088878e-12, -3.9844476254660645e-13)
# tuniv = 154.86 xuniv = 46.59%  Checking the solution:  1.919853165333052e-13
# Fold-change in tumor size: 0.34
# * Parameters: T = 40.0, Tbar = 13.0 (μ = 0.02500, μbar = 0.07692)
# Ending point: t = 23.65, x = 69.10%  Checking the solution: (-1.250972538647702e-07, 2.1720820826186482e-07)
# tuniv = 155.15 xuniv = 45.63%  Checking the solution:  -1.2406742300186124e-14
# Fold-change in tumor size: 0.32
# * Parameters: T = 40.0, Tbar = 12.0 (μ = 0.02500, μbar = 0.08333)
# Ending point: t = 23.38, x = 67.61%  Checking the solution: (5.635466492602288e-13, 5.844688369702243e-14)
# tuniv = 155.57 xuniv = 44.50%  Checking the solution:  2.131897436363772e-11
# Fold-change in tumor size: 0.29
# * Parameters: T = 40.0, Tbar = 11.0 (μ = 0.02500, μbar = 0.09091)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 23.13, x = 65.94%  Checking the solution: (-1.3167366570516808e-07, -9.327850990555137e-07)
# tuniv = 156.16 xuniv = 43.14%  Checking the solution:  3.3465452631276094e-12
# Fold-change in tumor size: 0.27
# * Parameters: T = 40.0, Tbar = 10.0 (μ = 0.02500, μbar = 0.10000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.82, x = 64.07%  Checking the solution: (8.348979264366653e-13, 8.304183501435444e-14)
# tuniv = 156.30 xuniv = 42.08%  Checking the solution:  2.7245983247325967e-12
# Fold-change in tumor size: 0.24
# * Parameters: T = 40.0, Tbar = 9.0 (μ = 0.02500, μbar = 0.11111)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 22.54, x = 61.95%  Checking the solution: (-1.1051590854938445e-11, -5.073334572509267e-13)
# tuniv = 156.66 xuniv = 40.71%  Checking the solution:  1.541289318396366e-11
# Fold-change in tumor size: 0.21
# * Parameters: T = 40.0, Tbar = 8.0 (μ = 0.02500, μbar = 0.12500)
# Ending point: t = 22.28, x = 59.52%  Checking the solution: (-1.2182626662426909e-07, -6.402836927138728e-08)
# tuniv = 157.03 xuniv = 39.19%  Checking the solution:  -1.4925283231548292e-12
# Fold-change in tumor size: 0.18
# * Parameters: T = 40.0, Tbar = 7.0 (μ = 0.02500, μbar = 0.14286)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 22.03, x = 56.69%  Checking the solution: (-1.2696654606353636e-07, 9.000341466334526e-07)
# tuniv = 157.12 xuniv = 37.66%  Checking the solution:  -2.1467411182030105e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 40.0, Tbar = 6.0 (μ = 0.02500, μbar = 0.16667)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 21.91, x = 53.34%  Checking the solution: (-1.4410244038429375e-07, 2.579016801042332e-09)
# tuniv = 157.56 xuniv = 35.64%  Checking the solution:  -3.489569744274945e-12
# Fold-change in tumor size: 0.13
# * Parameters: T = 40.0, Tbar = 5.0 (μ = 0.02500, μbar = 0.20000)
# Ending point: t = 21.98, x = 49.30%  Checking the solution: (-2.793074037690062e-11, -3.304244688911814e-12)
# tuniv = 157.58 xuniv = 33.48%  Checking the solution:  1.039959784954192e-12
# Fold-change in tumor size: 0.10
# * Parameters: T = 40.0, Tbar = 4.0 (μ = 0.02500, μbar = 0.25000)
# Ending point: t = 22.63, x = 44.27%  Checking the solution: (-3.466593186923563e-08, -3.0382430389077555e-07)
# tuniv = 157.10 xuniv = 30.91%  Checking the solution:  -2.51312859411712e-13
# Fold-change in tumor size: 0.07
# * Parameters: T = 39.0, Tbar = 40.0 (μ = 0.02564, μbar = 0.02500)
# Ending point: t = 28.09, x = 85.75%  Checking the solution: (-1.2044841332482857e-13, -5.9827135321314634e-15)
# tuniv = 148.63 xuniv = 61.80%  Checking the solution:  7.399858503731593e-12
# Fold-change in tumor size: 0.80
# * Parameters: T = 39.0, Tbar = 39.0 (μ = 0.02564, μbar = 0.02564)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.98, x = 85.48%  Checking the solution: (-1.3041523613935074e-14, -1.1593454850535339e-15)
# tuniv = 148.82 xuniv = 61.43%  Checking the solution:  1.4381648649752776e-11
# Fold-change in tumor size: 0.79
# * Parameters: T = 39.0, Tbar = 38.0 (μ = 0.02564, μbar = 0.02632)
# Ending point: t = 27.86, x = 85.19%  Checking the solution: (6.238430013186507e-14, 7.409342604585972e-15)
# tuniv = 149.02 xuniv = 61.06%  Checking the solution:  -7.341349750333848e-12
# Fold-change in tumor size: 0.78
# * Parameters: T = 39.0, Tbar = 37.0 (μ = 0.02564, μbar = 0.02703)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.73, x = 84.89%  Checking the solution: (1.0748198346977188e-13, 1.2494363981012133e-14)
# tuniv = 149.22 xuniv = 60.68%  Checking the solution:  4.982597667790856e-12
# Fold-change in tumor size: 0.77
# * Parameters: T = 39.0, Tbar = 36.0 (μ = 0.02564, μbar = 0.02778)
# Ending point: t = 27.61, x = 84.58%  Checking the solution: (3.970455568837216e-14, 2.017787109113096e-14)
# tuniv = 149.42 xuniv = 60.28%  Checking the solution:  -3.204075893492586e-12
# Fold-change in tumor size: 0.75
# * Parameters: T = 39.0, Tbar = 35.0 (μ = 0.02564, μbar = 0.02857)
# Ending point: t = 27.47, x = 84.25%  Checking the solution: (-5.4083502270305065e-08, 1.0550876714723489e-07)
# tuniv = 149.57 xuniv = 59.92%  Checking the solution:  1.686109585286033e-12
# Fold-change in tumor size: 0.74
# * Parameters: T = 39.0, Tbar = 34.0 (μ = 0.02564, μbar = 0.02941)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.37, x = 83.91%  Checking the solution: (-1.519518753891837e-07, -2.3944042761223625e-07)
# tuniv = 149.94 xuniv = 59.36%  Checking the solution:  1.5324963520413348e-12
# Fold-change in tumor size: 0.73
# * Parameters: T = 39.0, Tbar = 33.0 (μ = 0.02564, μbar = 0.03030)
# Ending point: t = 27.24, x = 83.55%  Checking the solution: (-1.8622573898565496e-07, -3.2860318669232665e-07)
# tuniv = 150.19 xuniv = 58.89%  Checking the solution:  -4.5913800539310046e-11
# Fold-change in tumor size: 0.71
# * Parameters: T = 39.0, Tbar = 32.0 (μ = 0.02564, μbar = 0.03125)
# Ending point: t = 27.08, x = 83.17%  Checking the solution: (-2.4690152541903095e-07, -1.602936637268385e-07)
# tuniv = 150.33 xuniv = 58.52%  Checking the solution:  9.698139513680815e-11
# Fold-change in tumor size: 0.70
# * Parameters: T = 39.0, Tbar = 31.0 (μ = 0.02564, μbar = 0.03226)
# Ending point: t = 26.94, x = 82.78%  Checking the solution: (-2.450201893533012e-07, -1.8672095403831875e-07)
# tuniv = 150.56 xuniv = 58.06%  Checking the solution:  3.8589548223555425e-12
# Fold-change in tumor size: 0.69
# * Parameters: T = 39.0, Tbar = 30.0 (μ = 0.02564, μbar = 0.03333)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.81, x = 82.37%  Checking the solution: (-2.275906049959267e-07, -4.579548083243705e-07)
# tuniv = 150.89 xuniv = 57.48%  Checking the solution:  -9.732908923254513e-13
# Fold-change in tumor size: 0.67
# * Parameters: T = 39.0, Tbar = 29.0 (μ = 0.02564, μbar = 0.03448)
# Ending point: t = 26.64, x = 81.93%  Checking the solution: (-1.7856835629133651e-07, -1.6579136548170603e-07)
# tuniv = 151.00 xuniv = 57.11%  Checking the solution:  -1.1041584313531416e-12
# Fold-change in tumor size: 0.66
# * Parameters: T = 39.0, Tbar = 28.0 (μ = 0.02564, μbar = 0.03571)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.48, x = 81.47%  Checking the solution: (-1.1122994669004882e-07, -2.0695277405834012e-07)
# tuniv = 151.25 xuniv = 56.59%  Checking the solution:  -3.441552598459907e-13
# Fold-change in tumor size: 0.64
# * Parameters: T = 39.0, Tbar = 27.0 (μ = 0.02564, μbar = 0.03704)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.31, x = 80.99%  Checking the solution: (-1.5322845852726125e-07, 3.0382140081769773e-08)
# tuniv = 151.40 xuniv = 56.16%  Checking the solution:  -1.33809630042947e-12
# Fold-change in tumor size: 0.62
# * Parameters: T = 39.0, Tbar = 26.0 (μ = 0.02564, μbar = 0.03846)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.14, x = 80.48%  Checking the solution: (5.23058122995149e-13, 5.229912026867956e-14)
# tuniv = 151.66 xuniv = 55.61%  Checking the solution:  -2.1422585927410864e-12
# Fold-change in tumor size: 0.61
# * Parameters: T = 39.0, Tbar = 25.0 (μ = 0.02564, μbar = 0.04000)
# Ending point: t = 26.00, x = 79.93%  Checking the solution: (-2.017312586546435e-07, -6.204309424370604e-07)
# tuniv = 152.14 xuniv = 54.83%  Checking the solution:  1.4390155733678966e-12
# Fold-change in tumor size: 0.59
# * Parameters: T = 39.0, Tbar = 24.0 (μ = 0.02564, μbar = 0.04167)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.80, x = 79.36%  Checking the solution: (-2.2851284754461966e-07, -1.8070677923781884e-07)
# tuniv = 152.23 xuniv = 54.40%  Checking the solution:  6.3200278344055505e-12
# Fold-change in tumor size: 0.57
# * Parameters: T = 39.0, Tbar = 23.0 (μ = 0.02564, μbar = 0.04348)
# Ending point: t = 25.61, x = 78.75%  Checking the solution: (-1.2951377793710356e-13, 1.3042079573837944e-13)
# tuniv = 152.43 xuniv = 53.86%  Checking the solution:  -5.358213872597162e-14
# Fold-change in tumor size: 0.55
# * Parameters: T = 39.0, Tbar = 22.0 (μ = 0.02564, μbar = 0.04545)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 25.37, x = 78.09%  Checking the solution: (-1.9804826519528997e-07, 7.994676479886016e-07)
# tuniv = 152.43 xuniv = 53.49%  Checking the solution:  -5.028741312251839e-12
# Fold-change in tumor size: 0.53
# * Parameters: T = 39.0, Tbar = 21.0 (μ = 0.02564, μbar = 0.04762)
# Ending point: t = 25.22, x = 77.40%  Checking the solution: (-2.2549664704398474e-13, -1.3712546972225938e-13)
# tuniv = 152.98 xuniv = 52.57%  Checking the solution:  -1.7301438060002283e-13
# Fold-change in tumor size: 0.51
# * Parameters: T = 39.0, Tbar = 20.0 (μ = 0.02564, μbar = 0.05000)
# Ending point: t = 25.02, x = 76.65%  Checking the solution: (-1.0724870472050451e-07, -2.00465444006526e-07)
# tuniv = 153.33 xuniv = 51.82%  Checking the solution:  -6.184566747613474e-13
# Fold-change in tumor size: 0.49
# * Parameters: T = 39.0, Tbar = 19.0 (μ = 0.02564, μbar = 0.05263)
# Ending point: t = 24.80, x = 75.84%  Checking the solution: (-3.5654123802550647e-12, 2.6146258278134886e-14)
# tuniv = 153.56 xuniv = 51.16%  Checking the solution:  -5.853137419187249e-12
# Fold-change in tumor size: 0.47
# * Parameters: T = 39.0, Tbar = 18.0 (μ = 0.02564, μbar = 0.05556)
# Ending point: t = 24.58, x = 74.98%  Checking the solution: (-5.448821224134179e-13, -2.6640304823679253e-14)
# tuniv = 153.87 xuniv = 50.40%  Checking the solution:  1.399352855813163e-12
# Fold-change in tumor size: 0.45
# * Parameters: T = 39.0, Tbar = 17.0 (μ = 0.02564, μbar = 0.05882)
# Ending point: t = 24.35, x = 74.04%  Checking the solution: (-2.824102272954603e-08, -3.220245789142785e-08)
# tuniv = 154.19 xuniv = 49.59%  Checking the solution:  -2.8857888301203616e-12
# Fold-change in tumor size: 0.43
# * Parameters: T = 39.0, Tbar = 16.0 (μ = 0.02564, μbar = 0.06250)
# Ending point: t = 24.15, x = 73.02%  Checking the solution: (-1.5618519897077956e-07, -9.662508043482477e-07)
# tuniv = 154.77 xuniv = 48.50%  Checking the solution:  4.437700207304829e-13
# Fold-change in tumor size: 0.40
# * Parameters: T = 39.0, Tbar = 15.0 (μ = 0.02564, μbar = 0.06667)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 23.88, x = 71.92%  Checking the solution: (-1.2247664369920131e-07, -1.7221227756254357e-07)
# tuniv = 154.87 xuniv = 47.82%  Checking the solution:  -2.5501781242276422e-11
# Fold-change in tumor size: 0.38
# * Parameters: T = 39.0, Tbar = 14.0 (μ = 0.02564, μbar = 0.07143)
# Ending point: t = 23.62, x = 70.70%  Checking the solution: (-2.2391230579746346e-12, -2.2739392948506633e-13)
# tuniv = 155.16 xuniv = 46.92%  Checking the solution:  -2.8971436361047154e-11
# Fold-change in tumor size: 0.35
# * Parameters: T = 39.0, Tbar = 13.0 (μ = 0.02564, μbar = 0.07692)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 23.38, x = 69.36%  Checking the solution: (-1.848039598122213e-07, -9.135002155484084e-07)
# tuniv = 155.74 xuniv = 45.70%  Checking the solution:  3.066158438258526e-13
# Fold-change in tumor size: 0.33
# * Parameters: T = 39.0, Tbar = 12.0 (μ = 0.02564, μbar = 0.08333)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 23.08, x = 67.88%  Checking the solution: (-1.4607861148915707e-07, -3.568891002241433e-08)
# tuniv = 155.87 xuniv = 44.82%  Checking the solution:  -7.33341581904412e-10
# Fold-change in tumor size: 0.30
# * Parameters: T = 39.0, Tbar = 11.0 (μ = 0.02564, μbar = 0.09091)
# Ending point: t = 22.81, x = 66.23%  Checking the solution: (-1.0067059633386037e-07, -4.235215822946133e-08)
# tuniv = 156.24 xuniv = 43.65%  Checking the solution:  -5.810071868062039e-11
# Fold-change in tumor size: 0.27
# * Parameters: T = 39.0, Tbar = 10.0 (μ = 0.02564, μbar = 0.10000)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 22.52, x = 64.37%  Checking the solution: (-2.367065581341536e-08, 9.395024753148682e-10)
# tuniv = 156.60 xuniv = 42.40%  Checking the solution:  7.851384820067864e-11
# Fold-change in tumor size: 0.25
# * Parameters: T = 39.0, Tbar = 9.0 (μ = 0.02564, μbar = 0.11111)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.24, x = 62.26%  Checking the solution: (-1.2235414724714186e-12, -1.3480828610757e-13)
# tuniv = 156.96 xuniv = 41.03%  Checking the solution:  2.1527085669603707e-12
# Fold-change in tumor size: 0.22
# * Parameters: T = 39.0, Tbar = 8.0 (μ = 0.02564, μbar = 0.12500)
# Ending point: t = 21.98, x = 59.84%  Checking the solution: (-1.17350811204289e-07, -3.4327913232284985e-07)
# tuniv = 157.40 xuniv = 39.46%  Checking the solution:  5.971168004492711e-12
# Fold-change in tumor size: 0.19
# * Parameters: T = 39.0, Tbar = 7.0 (μ = 0.02564, μbar = 0.14286)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 21.73, x = 57.02%  Checking the solution: (-1.3145470442862333e-07, 5.818650267757817e-07)
# tuniv = 157.50 xuniv = 37.92%  Checking the solution:  1.3686274336066617e-12
# Fold-change in tumor size: 0.16
# * Parameters: T = 39.0, Tbar = 6.0 (μ = 0.02564, μbar = 0.16667)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 21.59, x = 53.69%  Checking the solution: (-1.4160965241839395e-07, -2.8555241156983773e-07)
# tuniv = 157.95 xuniv = 35.90%  Checking the solution:  -1.9873727663544116e-11
# Fold-change in tumor size: 0.13
# * Parameters: T = 39.0, Tbar = 5.0 (μ = 0.02564, μbar = 0.20000)
# Ending point: t = 21.63, x = 49.66%  Checking the solution: (-1.1023721815150098e-11, -1.2775348965309755e-12)
# tuniv = 157.93 xuniv = 33.77%  Checking the solution:  -3.0560276531588215e-13
# Fold-change in tumor size: 0.10
# * Parameters: T = 39.0, Tbar = 4.0 (μ = 0.02564, μbar = 0.25000)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.23, x = 44.64%  Checking the solution: (-3.980447942312814e-07, -6.356775751923072e-07)
# tuniv = 157.61 xuniv = 31.16%  Checking the solution:  -2.6006974351844292e-14
# Fold-change in tumor size: 0.08
# * Parameters: T = 38.0, Tbar = 40.0 (μ = 0.02632, μbar = 0.02500)
# Ending point: t = 27.75, x = 85.90%  Checking the solution: (4.9948743888395724e-14, -2.8602733271669666e-15)
# tuniv = 148.98 xuniv = 62.14%  Checking the solution:  -1.531878790483887e-11
# Fold-change in tumor size: 0.82
# * Parameters: T = 38.0, Tbar = 39.0 (μ = 0.02632, μbar = 0.02564)
# Ending point: t = 27.64, x = 85.62%  Checking the solution: (-1.279759184705958e-13, 4.999333411634882e-16)
# tuniv = 149.16 xuniv = 61.77%  Checking the solution:  -1.7548601460859459e-12
# Fold-change in tumor size: 0.81
# * Parameters: T = 38.0, Tbar = 38.0 (μ = 0.02632, μbar = 0.02632)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 27.52, x = 85.34%  Checking the solution: (-1.0277270905604912e-12, -6.401592967761754e-13)
# tuniv = 149.36 xuniv = 61.40%  Checking the solution:  -1.2800857596140247e-11
# Fold-change in tumor size: 0.80
# * Parameters: T = 38.0, Tbar = 37.0 (μ = 0.02632, μbar = 0.02703)
# Ending point: t = 27.40, x = 85.04%  Checking the solution: (3.637527574191274e-14, 3.761398605531791e-15)
# tuniv = 149.55 xuniv = 61.02%  Checking the solution:  -3.3725217063462765e-11
# Fold-change in tumor size: 0.78
# * Parameters: T = 38.0, Tbar = 36.0 (μ = 0.02632, μbar = 0.02778)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.28, x = 84.73%  Checking the solution: (8.24200462653385e-14, 8.591009540041459e-15)
# tuniv = 149.75 xuniv = 60.63%  Checking the solution:  5.509481759702339e-12
# Fold-change in tumor size: 0.77
# * Parameters: T = 38.0, Tbar = 35.0 (μ = 0.02632, μbar = 0.02857)
# Ending point: t = 27.15, x = 84.41%  Checking the solution: (-1.0969701674701843e-07, 5.288934603148935e-09)
# tuniv = 149.95 xuniv = 60.22%  Checking the solution:  6.339095914853488e-13
# Fold-change in tumor size: 0.76
# * Parameters: T = 38.0, Tbar = 34.0 (μ = 0.02632, μbar = 0.02941)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 27.03, x = 84.07%  Checking the solution: (-1.4899128666666376e-07, -2.0936418289145553e-07)
# tuniv = 150.26 xuniv = 59.71%  Checking the solution:  -1.7337686841756295e-11
# Fold-change in tumor size: 0.74
# * Parameters: T = 38.0, Tbar = 33.0 (μ = 0.02632, μbar = 0.03030)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.90, x = 83.71%  Checking the solution: (-1.8300266383617463e-07, -2.4604201711467906e-07)
# tuniv = 150.48 xuniv = 59.27%  Checking the solution:  -1.2787812475600902e-10
# Fold-change in tumor size: 0.73
# * Parameters: T = 38.0, Tbar = 32.0 (μ = 0.02632, μbar = 0.03125)
# Ending point: t = 26.78, x = 83.34%  Checking the solution: (-2.5170111193328966e-07, -5.536045295263385e-07)
# tuniv = 150.83 xuniv = 58.70%  Checking the solution:  2.8523433615035287e-12
# Fold-change in tumor size: 0.72
# * Parameters: T = 38.0, Tbar = 31.0 (μ = 0.02632, μbar = 0.03226)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.62, x = 82.95%  Checking the solution: (-2.416875689659615e-07, -2.589705298045497e-07)
# tuniv = 150.92 xuniv = 58.37%  Checking the solution:  3.4659081160626215e-12
# Fold-change in tumor size: 0.70
# * Parameters: T = 38.0, Tbar = 30.0 (μ = 0.02632, μbar = 0.03333)
# Ending point: t = 26.46, x = 82.54%  Checking the solution: (-2.1960613927652758e-07, -5.0835611418730854e-08)
# tuniv = 151.06 xuniv = 57.99%  Checking the solution:  7.648021105310931e-12
# Fold-change in tumor size: 0.69
# * Parameters: T = 38.0, Tbar = 29.0 (μ = 0.02632, μbar = 0.03448)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.33, x = 82.11%  Checking the solution: (-1.824821725444593e-07, -3.6382683210472603e-07)
# tuniv = 151.41 xuniv = 57.38%  Checking the solution:  -1.4894890876249178e-12
# Fold-change in tumor size: 0.67
# * Parameters: T = 38.0, Tbar = 28.0 (μ = 0.02632, μbar = 0.03571)
# Ending point: t = 26.18, x = 81.65%  Checking the solution: (-1.1819077875064842e-07, -4.710586091887195e-07)
# tuniv = 151.68 xuniv = 56.84%  Checking the solution:  2.4679980281661074e-12
# Fold-change in tumor size: 0.65
# * Parameters: T = 38.0, Tbar = 27.0 (μ = 0.02632, μbar = 0.03704)
# Ending point: t = 26.00, x = 81.17%  Checking the solution: (-2.499108999388479e-08, -1.8909623096053335e-07)
# tuniv = 151.81 xuniv = 56.43%  Checking the solution:  -5.816888637433237e-12
# Fold-change in tumor size: 0.64
# * Parameters: T = 38.0, Tbar = 26.0 (μ = 0.02632, μbar = 0.03846)
# Ending point: t = 25.82, x = 80.67%  Checking the solution: (1.3308574504537207e-13, 1.2881858768543936e-14)
# tuniv = 151.98 xuniv = 55.96%  Checking the solution:  1.526868909085266e-11
# Fold-change in tumor size: 0.62
# * Parameters: T = 38.0, Tbar = 25.0 (μ = 0.02632, μbar = 0.04000)
# Ending point: t = 25.69, x = 80.13%  Checking the solution: (-1.917220993174112e-07, -7.527934300303923e-07)
# tuniv = 152.50 xuniv = 55.13%  Checking the solution:  -2.5704438577633937e-13
# Fold-change in tumor size: 0.60
# * Parameters: T = 38.0, Tbar = 24.0 (μ = 0.02632, μbar = 0.04167)
# Ending point: t = 25.44, x = 79.56%  Checking the solution: (-2.2533884555069378e-07, 6.514393177995369e-07)
# tuniv = 152.25 xuniv = 55.04%  Checking the solution:  -3.979261364861486e-12
# Fold-change in tumor size: 0.58
# * Parameters: T = 38.0, Tbar = 23.0 (μ = 0.02632, μbar = 0.04348)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 25.32, x = 78.95%  Checking the solution: (-2.1705051053759217e-07, -4.955858325459409e-07)
# tuniv = 152.92 xuniv = 54.04%  Checking the solution:  6.380243555703657e-13
# Fold-change in tumor size: 0.56
# * Parameters: T = 38.0, Tbar = 22.0 (μ = 0.02632, μbar = 0.04545)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.10, x = 78.30%  Checking the solution: (-2.14034104194423e-07, -9.386501484116936e-10)
# tuniv = 153.02 xuniv = 53.58%  Checking the solution:  1.0461215227408616e-12
# Fold-change in tumor size: 0.54
# * Parameters: T = 38.0, Tbar = 21.0 (μ = 0.02632, μbar = 0.04762)
# Ending point: t = 24.90, x = 77.61%  Checking the solution: (1.5923162311262673e-14, 4.3050462004415585e-15)
# tuniv = 153.30 xuniv = 52.92%  Checking the solution:  -9.504827480633082e-13
# Fold-change in tumor size: 0.52
# * Parameters: T = 38.0, Tbar = 20.0 (μ = 0.02632, μbar = 0.05000)
# Ending point: t = 24.72, x = 76.87%  Checking the solution: (-1.68321362450026e-07, -3.769498076774185e-07)
# tuniv = 153.70 xuniv = 52.11%  Checking the solution:  4.1667662376010384e-11
# Fold-change in tumor size: 0.50
# * Parameters: T = 38.0, Tbar = 19.0 (μ = 0.02632, μbar = 0.05263)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 24.49, x = 76.07%  Checking the solution: (2.8894344992594366e-13, 1.1928784033453304e-13)
# tuniv = 153.87 xuniv = 51.50%  Checking the solution:  6.309917865987558e-12
# Fold-change in tumor size: 0.48
# * Parameters: T = 38.0, Tbar = 18.0 (μ = 0.02632, μbar = 0.05556)
# Ending point: t = 24.27, x = 75.21%  Checking the solution: (1.96564424080007e-13, 2.008158651557203e-14)
# tuniv = 154.18 xuniv = 50.75%  Checking the solution:  -2.618770478246546e-11
# Fold-change in tumor size: 0.46
# * Parameters: T = 38.0, Tbar = 17.0 (μ = 0.02632, μbar = 0.05882)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 24.05, x = 74.28%  Checking the solution: (-4.35416681240368e-09, -8.50303527579287e-08)
# tuniv = 154.51 xuniv = 49.92%  Checking the solution:  -3.680208915390892e-12
# Fold-change in tumor size: 0.44
# * Parameters: T = 38.0, Tbar = 16.0 (μ = 0.02632, μbar = 0.06250)
# Ending point: t = 23.82, x = 73.27%  Checking the solution: (-1.459102843193079e-07, -3.6427258584019657e-07)
# tuniv = 154.91 xuniv = 49.01%  Checking the solution:  -1.5127107899637338e-11
# Fold-change in tumor size: 0.41
# * Parameters: T = 38.0, Tbar = 15.0 (μ = 0.02632, μbar = 0.06667)
# Ending point: t = 23.59, x = 72.17%  Checking the solution: (-1.3957409699437682e-07, -5.883432009308316e-07)
# tuniv = 155.29 xuniv = 48.06%  Checking the solution:  -2.340488913787908e-12
# Fold-change in tumor size: 0.39
# * Parameters: T = 38.0, Tbar = 14.0 (μ = 0.02632, μbar = 0.07143)
# Ending point: t = 23.31, x = 70.96%  Checking the solution: (-1.977751563729665e-12, 1.0761183560788739e-14)
# tuniv = 155.47 xuniv = 47.26%  Checking the solution:  -1.9774029635932777e-11
# Fold-change in tumor size: 0.36
# * Parameters: T = 38.0, Tbar = 13.0 (μ = 0.02632, μbar = 0.07692)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 23.07, x = 69.64%  Checking the solution: (-1.5796032036378526e-07, -5.800238497871807e-07)
# tuniv = 155.96 xuniv = 46.11%  Checking the solution:  -5.41836020495623e-12
# Fold-change in tumor size: 0.34
# * Parameters: T = 38.0, Tbar = 12.0 (μ = 0.02632, μbar = 0.08333)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 22.78, x = 68.16%  Checking the solution: (2.166198223651795e-12, 2.353076407223693e-13)
# tuniv = 156.17 xuniv = 45.16%  Checking the solution:  3.3894137496659482e-12
# Fold-change in tumor size: 0.31
# * Parameters: T = 38.0, Tbar = 11.0 (μ = 0.02632, μbar = 0.09091)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 22.50, x = 66.52%  Checking the solution: (-6.303839016771993e-08, -4.9943217210173126e-08)
# tuniv = 156.54 xuniv = 43.99%  Checking the solution:  3.4509853308328786e-11
# Fold-change in tumor size: 0.28
# * Parameters: T = 38.0, Tbar = 10.0 (μ = 0.02632, μbar = 0.10000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 22.22, x = 64.67%  Checking the solution: (-7.097142346620231e-08, -8.630094974169537e-08)
# tuniv = 156.92 xuniv = 42.72%  Checking the solution:  -1.4009998716701944e-10
# Fold-change in tumor size: 0.25
# * Parameters: T = 38.0, Tbar = 9.0 (μ = 0.02632, μbar = 0.11111)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 21.94, x = 62.57%  Checking the solution: (-6.460113959610323e-08, -4.3359766124202384e-08)
# tuniv = 157.28 xuniv = 41.35%  Checking the solution:  -8.036626919505352e-13
# Fold-change in tumor size: 0.22
# * Parameters: T = 38.0, Tbar = 8.0 (μ = 0.02632, μbar = 0.12500)
# Ending point: t = 21.66, x = 60.16%  Checking the solution: (2.231268547712767e-12, 2.4960049775784733e-13)
# tuniv = 157.63 xuniv = 39.84%  Checking the solution:  7.710360128143634e-13
# Fold-change in tumor size: 0.19
# * Parameters: T = 38.0, Tbar = 7.0 (μ = 0.02632, μbar = 0.14286)
# Ending point: t = 21.42, x = 57.36%  Checking the solution: (-1.3671549448724023e-07, -2.2360478667431453e-09)
# tuniv = 157.95 xuniv = 38.15%  Checking the solution:  6.574879529708255e-13
# Fold-change in tumor size: 0.16
# * Parameters: T = 38.0, Tbar = 6.0 (μ = 0.02632, μbar = 0.16667)
# Ending point: t = 21.26, x = 54.04%  Checking the solution: (-1.4377135383600707e-07, -3.8180525199398637e-07)
# tuniv = 158.30 xuniv = 36.20%  Checking the solution:  1.0078909928878943e-11
# Fold-change in tumor size: 0.14
# * Parameters: T = 38.0, Tbar = 5.0 (μ = 0.02632, μbar = 0.20000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 21.27, x = 50.03%  Checking the solution: (-7.349848993051052e-12, -9.57244262560621e-13)
# tuniv = 158.28 xuniv = 34.07%  Checking the solution:  4.022324140429134e-12
# Fold-change in tumor size: 0.11
# * Parameters: T = 38.0, Tbar = 4.0 (μ = 0.02632, μbar = 0.25000)
# Ending point: t = 21.81, x = 45.03%  Checking the solution: (-3.3602677213992695e-07, -1.6947472266355484e-07)
# tuniv = 157.89 xuniv = 31.49%  Checking the solution:  -2.375573696089539e-14
# Fold-change in tumor size: 0.08
# * Parameters: T = 37.0, Tbar = 40.0 (μ = 0.02703, μbar = 0.02500)
# Ending point: t = 27.41, x = 86.04%  Checking the solution: (-1.2240235333212612e-12, -1.1806911713137134e-12)
# tuniv = 149.32 xuniv = 62.49%  Checking the solution:  -4.055117353019e-12
# Fold-change in tumor size: 0.84
# * Parameters: T = 37.0, Tbar = 39.0 (μ = 0.02703, μbar = 0.02564)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 27.29, x = 85.77%  Checking the solution: (1.600335905189553e-13, 1.9524352842608183e-14)
# tuniv = 149.51 xuniv = 62.12%  Checking the solution:  -1.8145762670229715e-12
# Fold-change in tumor size: 0.82
# * Parameters: T = 37.0, Tbar = 38.0 (μ = 0.02703, μbar = 0.02632)
# Ending point: t = 27.18, x = 85.49%  Checking the solution: (-7.856013533590902e-14, -4.137274670998264e-14)
# tuniv = 149.70 xuniv = 61.75%  Checking the solution:  9.676703882632864e-12
# Fold-change in tumor size: 0.81
# * Parameters: T = 37.0, Tbar = 37.0 (μ = 0.02703, μbar = 0.02703)
# Ending point: t = 27.06, x = 85.20%  Checking the solution: (6.983541592892154e-14, 6.993930976251484e-15)
# tuniv = 149.90 xuniv = 61.37%  Checking the solution:  2.1824372344048104e-10
# Fold-change in tumor size: 0.80
# * Parameters: T = 37.0, Tbar = 36.0 (μ = 0.02703, μbar = 0.02778)
# Ending point: t = 26.94, x = 84.89%  Checking the solution: (-1.867958740128238e-09, -8.766741997766618e-08)
# tuniv = 150.14 xuniv = 60.94%  Checking the solution:  -1.626879186922281e-12
# Fold-change in tumor size: 0.79
# * Parameters: T = 37.0, Tbar = 35.0 (μ = 0.02703, μbar = 0.02857)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 26.84, x = 84.57%  Checking the solution: (-1.1058004653284776e-07, -4.1607881760714205e-07)
# tuniv = 150.49 xuniv = 60.39%  Checking the solution:  -1.5107456952101472e-11
# Fold-change in tumor size: 0.77
# * Parameters: T = 37.0, Tbar = 34.0 (μ = 0.02703, μbar = 0.02941)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 26.68, x = 84.23%  Checking the solution: (-1.476801613727612e-07, -9.199639663205533e-08)
# tuniv = 150.55 xuniv = 60.12%  Checking the solution:  -4.630185124199215e-13
# Fold-change in tumor size: 0.76
# * Parameters: T = 37.0, Tbar = 33.0 (μ = 0.02703, μbar = 0.03030)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 26.57, x = 83.88%  Checking the solution: (-2.3427016080235407e-07, -4.0293346183579634e-07)
# tuniv = 150.89 xuniv = 59.56%  Checking the solution:  -1.379167960391392e-11
# Fold-change in tumor size: 0.74
# * Parameters: T = 37.0, Tbar = 32.0 (μ = 0.02703, μbar = 0.03125)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 26.42, x = 83.51%  Checking the solution: (-2.3917006870675225e-07, -2.0379534360390845e-07)
# tuniv = 151.02 xuniv = 59.20%  Checking the solution:  -1.1582683423494444e-10
# Fold-change in tumor size: 0.73
# * Parameters: T = 37.0, Tbar = 31.0 (μ = 0.02703, μbar = 0.03226)
# Ending point: t = 26.31, x = 83.13%  Checking the solution: (-2.499532243891743e-07, -6.588986605099727e-07)
# tuniv = 151.42 xuniv = 58.56%  Checking the solution:  9.875711359796924e-13
# Fold-change in tumor size: 0.72
# * Parameters: T = 37.0, Tbar = 30.0 (μ = 0.02703, μbar = 0.03333)
# Ending point: t = 26.12, x = 82.72%  Checking the solution: (-2.1721633380753148e-07, 3.1113928902594206e-09)
# tuniv = 151.37 xuniv = 58.36%  Checking the solution:  7.462086504261833e-13
# Fold-change in tumor size: 0.70
# * Parameters: T = 37.0, Tbar = 29.0 (μ = 0.02703, μbar = 0.03448)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.99, x = 82.29%  Checking the solution: (-1.7974178450339582e-07, -3.519616078144776e-07)
# tuniv = 151.74 xuniv = 57.74%  Checking the solution:  -1.813119099303151e-12
# Fold-change in tumor size: 0.68
# * Parameters: T = 37.0, Tbar = 28.0 (μ = 0.02703, μbar = 0.03571)
# Ending point: t = 25.87, x = 81.84%  Checking the solution: (-1.2736399341432614e-07, -8.45328695788601e-07)
# tuniv = 152.16 xuniv = 57.05%  Checking the solution:  -9.272999035303542e-13
# Fold-change in tumor size: 0.67
# * Parameters: T = 37.0, Tbar = 27.0 (μ = 0.02703, μbar = 0.03704)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 25.66, x = 81.37%  Checking the solution: (-2.75134498913994e-08, 1.472907577213973e-09)
# tuniv = 152.07 xuniv = 56.85%  Checking the solution:  1.9186319200059643e-12
# Fold-change in tumor size: 0.65
# * Parameters: T = 37.0, Tbar = 26.0 (μ = 0.02703, μbar = 0.03846)
# Ending point: t = 25.49, x = 80.86%  Checking the solution: (-1.0654164000191347e-12, -2.3944009046763574e-13)
# tuniv = 152.31 xuniv = 56.31%  Checking the solution:  2.408948041043857e-12
# Fold-change in tumor size: 0.63
# * Parameters: T = 37.0, Tbar = 25.0 (μ = 0.02703, μbar = 0.04000)
# Ending point: t = 25.34, x = 80.33%  Checking the solution: (-1.652487464089039e-07, -3.5843755056710707e-07)
# tuniv = 152.69 xuniv = 55.63%  Checking the solution:  -3.399378001311959e-12
# Fold-change in tumor size: 0.61
# * Parameters: T = 37.0, Tbar = 24.0 (μ = 0.02703, μbar = 0.04167)
# Ending point: t = 25.17, x = 79.76%  Checking the solution: (-2.240852064079567e-07, -4.462741286905271e-07)
# tuniv = 152.97 xuniv = 55.02%  Checking the solution:  3.3363728446644814e-12
# Fold-change in tumor size: 0.60
# * Parameters: T = 37.0, Tbar = 23.0 (μ = 0.02703, μbar = 0.04348)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 24.97, x = 79.16%  Checking the solution: (-2.168088411371419e-07, -8.880761934113035e-09)
# tuniv = 153.08 xuniv = 54.56%  Checking the solution:  -1.5451209756101036e-11
# Fold-change in tumor size: 0.58
# * Parameters: T = 37.0, Tbar = 22.0 (μ = 0.02703, μbar = 0.04545)
# Ending point: t = 24.80, x = 78.52%  Checking the solution: (-2.254767803809836e-07, -4.929776434007996e-07)
# tuniv = 153.51 xuniv = 53.77%  Checking the solution:  -3.276476312485954e-13
# Fold-change in tumor size: 0.56
# * Parameters: T = 37.0, Tbar = 21.0 (μ = 0.02703, μbar = 0.04762)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 24.58, x = 77.83%  Checking the solution: (2.911132551840001e-13, 1.987894140188396e-14)
# tuniv = 153.62 xuniv = 53.27%  Checking the solution:  -2.5711377471537844e-13
# Fold-change in tumor size: 0.54
# * Parameters: T = 37.0, Tbar = 20.0 (μ = 0.02703, μbar = 0.05000)
# Ending point: t = 24.40, x = 77.09%  Checking the solution: (-1.4667856893133007e-07, -4.501721769607694e-07)
# tuniv = 154.04 xuniv = 52.44%  Checking the solution:  1.8148302305398545e-11
# Fold-change in tumor size: 0.51
# * Parameters: T = 37.0, Tbar = 19.0 (μ = 0.02703, μbar = 0.05263)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 24.17, x = 76.30%  Checking the solution: (-1.4545638171914853e-13, -1.6016771811053063e-14)
# tuniv = 154.19 xuniv = 51.86%  Checking the solution:  -8.514119964608824e-12
# Fold-change in tumor size: 0.49
# * Parameters: T = 37.0, Tbar = 18.0 (μ = 0.02703, μbar = 0.05556)
# Ending point: t = 23.96, x = 75.45%  Checking the solution: (-4.2830906058161436e-12, -1.3724768939380934e-12)
# tuniv = 154.49 xuniv = 51.10%  Checking the solution:  -3.183039942733501e-11
# Fold-change in tumor size: 0.47
# * Parameters: T = 37.0, Tbar = 17.0 (μ = 0.02703, μbar = 0.05882)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 23.73, x = 74.53%  Checking the solution: (1.2018735649993537e-13, 1.2935690636716217e-14)
# tuniv = 154.80 xuniv = 50.30%  Checking the solution:  -2.791128439483259e-12
# Fold-change in tumor size: 0.45
# * Parameters: T = 37.0, Tbar = 16.0 (μ = 0.02703, μbar = 0.06250)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ...
# * Parameters: T = 5.0, Tbar = 11.0 (μ = 0.20000, μbar = 0.09091)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 6.46, x = 87.50%  Checking the solution: (-2.5114070729036372e-08, -5.434114071692297e-07)
# tuniv = 172.73 xuniv = 70.46%  Checking the solution:  -8.028473719168261e-14
# Fold-change in tumor size: 1.57
# * Parameters: T = 5.0, Tbar = 10.0 (μ = 0.20000, μbar = 0.10000)
# Ending point: t = 6.34, x = 86.61%  Checking the solution: (-3.5567995751129415e-07, -1.7052977631474295e-07)
# tuniv = 172.86 xuniv = 69.42%  Checking the solution:  1.609823385706477e-15
# Fold-change in tumor size: 1.48
# * Parameters: T = 5.0, Tbar = 9.0 (μ = 0.20000, μbar = 0.11111)
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# Ending point: t = 6.20, x = 85.56%  Checking the solution: (-2.844531133128738e-07, -1.2237497917544663e-08)
# tuniv = 173.05 xuniv = 68.13%  Checking the solution:  -1.8707257964933888e-14
# Fold-change in tumor size: 1.39
# * Parameters: T = 5.0, Tbar = 8.0 (μ = 0.20000, μbar = 0.12500)
# Ending point: t = 6.06, x = 84.31%  Checking the solution: (-1.2515125791813394e-07, -3.99944676964652e-07)
# tuniv = 173.32 xuniv = 66.42%  Checking the solution:  6.386557949156213e-14
# Fold-change in tumor size: 1.28
# * Parameters: T = 5.0, Tbar = 7.0 (μ = 0.20000, μbar = 0.14286)
# Ending point: t = 5.90, x = 82.81%  Checking the solution: (-2.5214930784936114e-07, -7.39744143677133e-07)
# tuniv = 173.60 xuniv = 64.53%  Checking the solution:  -1.2977119379087299e-13
# Fold-change in tumor size: 1.16
# * Parameters: T = 5.0, Tbar = 6.0 (μ = 0.20000, μbar = 0.16667)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 5.72, x = 80.95%  Checking the solution: (-1.7563069178283284e-07, -1.1702873749946003e-07)
# tuniv = 173.78 xuniv = 62.72%  Checking the solution:  8.545247842661752e-15
# Fold-change in tumor size: 1.03
# * Parameters: T = 5.0, Tbar = 5.0 (μ = 0.20000, μbar = 0.20000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 5.51, x = 78.58%  Checking the solution: (-8.337598846737081e-08, 2.713818071191354e-07)
# tuniv = 174.03 xuniv = 60.39%  Checking the solution:  -8.465450562766819e-15
# Fold-change in tumor size: 0.88
# * Parameters: T = 5.0, Tbar = 4.0 (μ = 0.20000, μbar = 0.25000)
# Ending point: t = 5.26, x = 75.43%  Checking the solution: (1.1599230385591405e-12, 5.741948337096609e-13)
# tuniv = 174.39 xuniv = 57.27%  Checking the solution:  -1.3034434642733572e-12
# Fold-change in tumor size: 0.72
# * Parameters: T = 4.0, Tbar = 40.0 (μ = 0.25000, μbar = 0.02500)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 6.71, x = 96.28%  Checking the solution: (1.5552659512221801e-13, 7.607873524663389e-14)
# tuniv = 170.73 xuniv = 87.17%  Checking the solution:  -9.62840918106167e-14
# Fold-change in tumor size: 2.85
# * Parameters: T = 4.0, Tbar = 39.0 (μ = 0.25000, μbar = 0.02564)
# Ending point: t = 6.69, x = 96.20%  Checking the solution: (4.627112847819856e-13, -1.1792965258178002e-12)
# tuniv = 170.79 xuniv = 86.95%  Checking the solution:  2.7221280785028057e-14
# Fold-change in tumor size: 2.83
# * Parameters: T = 4.0, Tbar = 38.0 (μ = 0.25000, μbar = 0.02632)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 6.69, x = 96.11%  Checking the solution: (-1.4428156048608136e-08, -8.443803391720094e-07)
# tuniv = 171.22 xuniv = 86.01%  Checking the solution:  -1.1761550067213022e-11
# Fold-change in tumor size: 2.82
# * Parameters: T = 4.0, Tbar = 37.0 (μ = 0.25000, μbar = 0.02703)
# Ending point: t = 6.65, x = 96.02%  Checking the solution: (-1.8029262953309896e-08, 6.7924369442432845e-09)
# tuniv = 170.93 xuniv = 86.50%  Checking the solution:  -8.478495683306164e-13
# Fold-change in tumor size: 2.80
# * Parameters: T = 4.0, Tbar = 36.0 (μ = 0.25000, μbar = 0.02778)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 6.63, x = 95.92%  Checking the solution: (-1.6531167414134553e-08, -6.491589105526482e-08)
# tuniv = 171.03 xuniv = 86.19%  Checking the solution:  8.423817199343375e-15
# Fold-change in tumor size: 2.78
# * Parameters: T = 4.0, Tbar = 35.0 (μ = 0.25000, μbar = 0.02857)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 6.60, x = 95.82%  Checking the solution: (6.334381974272901e-12, 1.200619781922545e-12)
# tuniv = 171.08 xuniv = 85.99%  Checking the solution:  -2.850289448907972e-12
# Fold-change in tumor size: 2.77
# * Parameters: T = 4.0, Tbar = 34.0 (μ = 0.25000, μbar = 0.02941)
# Ending point: t = 6.58, x = 95.71%  Checking the solution: (2.615301767196817e-12, 7.457953864493793e-12)
# tuniv = 171.15 xuniv = 85.73%  Checking the solution:  2.3564483697668948e-14
# Fold-change in tumor size: 2.75
# * Parameters: T = 4.0, Tbar = 33.0 (μ = 0.25000, μbar = 0.03030)
# Ending point: t = 6.55, x = 95.60%  Checking the solution: (5.543126221769471e-13, 2.8008682892279304e-13)
# tuniv = 171.23 xuniv = 85.45%  Checking the solution:  1.5126788710517758e-15
# Fold-change in tumor size: 2.73
# * Parameters: T = 4.0, Tbar = 32.0 (μ = 0.25000, μbar = 0.03125)
# Ending point: t = 6.53, x = 95.48%  Checking the solution: (-2.7347674179277034e-09, -1.9972809256151827e-08)
# tuniv = 171.31 xuniv = 85.15%  Checking the solution:  -1.3475331961387838e-14
# Fold-change in tumor size: 2.71
# * Parameters: T = 4.0, Tbar = 31.0 (μ = 0.25000, μbar = 0.03226)
# Ending point: t = 6.50, x = 95.35%  Checking the solution: (-2.1606045035013847e-08, 5.2728568590188645e-09)
# tuniv = 171.38 xuniv = 84.87%  Checking the solution:  6.217248937900877e-15
# Fold-change in tumor size: 2.68
# * Parameters: T = 4.0, Tbar = 30.0 (μ = 0.25000, μbar = 0.03333)
# Ending point: t = 6.47, x = 95.22%  Checking the solution: (-3.334845484187184e-08, 2.497032680600935e-08)
# tuniv = 171.46 xuniv = 84.57%  Checking the solution:  2.3592239273284576e-15
# Fold-change in tumor size: 2.66
# * Parameters: T = 4.0, Tbar = 29.0 (μ = 0.25000, μbar = 0.03448)
# Ending point: t = 6.44, x = 95.08%  Checking the solution: (-1.9967400879662514e-08, -5.168290641680321e-11)
# tuniv = 171.55 xuniv = 84.23%  Checking the solution:  -1.915134717478395e-14
# Fold-change in tumor size: 2.64
# * Parameters: T = 4.0, Tbar = 28.0 (μ = 0.25000, μbar = 0.03571)
# Ending point: t = 6.41, x = 94.93%  Checking the solution: (-2.2397473982617015e-08, 6.1553818102521e-11)
# tuniv = 171.64 xuniv = 83.88%  Checking the solution:  1.4238610290817633e-14
# Fold-change in tumor size: 2.61
# * Parameters: T = 4.0, Tbar = 27.0 (μ = 0.25000, μbar = 0.03704)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 6.38, x = 94.77%  Checking the solution: (-4.1383098395810164e-08, -1.0074719790402444e-07)
# tuniv = 171.76 xuniv = 83.45%  Checking the solution:  -5.773159728050814e-15
# Fold-change in tumor size: 2.58
# * Parameters: T = 4.0, Tbar = 26.0 (μ = 0.25000, μbar = 0.03846)
# Ending point: t = 6.34, x = 94.60%  Checking the solution: (-2.554003239590136e-08, -1.2861603042737963e-09)
# tuniv = 171.81 xuniv = 83.15%  Checking the solution:  9.71445146547012e-16
# Fold-change in tumor size: 2.56
# * Parameters: T = 4.0, Tbar = 25.0 (μ = 0.25000, μbar = 0.04000)
# Ending point: t = 6.31, x = 94.41%  Checking the solution: (-2.5776386282375548e-08, -7.26954413365203e-08)
# tuniv = 171.93 xuniv = 82.70%  Checking the solution:  -3.534672554650342e-14
# Fold-change in tumor size: 2.53
# * Parameters: T = 4.0, Tbar = 24.0 (μ = 0.25000, μbar = 0.04167)
# Ending point: t = 6.27, x = 94.22%  Checking the solution: (-1.693617543407073e-08, 8.02664633558181e-09)
# tuniv = 172.00 xuniv = 82.34%  Checking the solution:  -1.1948775302528247e-14
# Fold-change in tumor size: 2.50
# * Parameters: T = 4.0, Tbar = 23.0 (μ = 0.25000, μbar = 0.04348)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 6.23, x = 94.01%  Checking the solution: (-1.8243082204634365e-08, -8.72079976202406e-12)
# tuniv = 172.10 xuniv = 81.89%  Checking the solution:  -8.520961713998076e-15
# Fold-change in tumor size: 2.46
# * Parameters: T = 4.0, Tbar = 22.0 (μ = 0.25000, μbar = 0.04545)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 6.19, x = 93.78%  Checking the solution: (-1.396940995520137e-08, 2.4852090601867756e-09)
# tuniv = 172.20 xuniv = 81.43%  Checking the solution:  5.6066262743570405e-15
# Fold-change in tumor size: 2.43
# * Parameters: T = 4.0, Tbar = 21.0 (μ = 0.25000, μbar = 0.04762)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 6.14, x = 93.54%  Checking the solution: (-1.8291698363590645e-08, 5.714980925961518e-10)
# tuniv = 172.31 xuniv = 80.93%  Checking the solution:  -5.245803791353865e-15
# Fold-change in tumor size: 2.39
# * Parameters: T = 4.0, Tbar = 20.0 (μ = 0.25000, μbar = 0.05000)
# Ending point: t = 6.10, x = 93.27%  Checking the solution: (-4.4211071452703076e-14, -2.1627541212905164e-14)
# tuniv = 172.42 xuniv = 80.40%  Checking the solution:  1.8235413179468196e-14
# Fold-change in tumor size: 2.35
# * Parameters: T = 4.0, Tbar = 19.0 (μ = 0.25000, μbar = 0.05263)
# Ending point: t = 6.05, x = 92.98%  Checking the solution: (-2.8082794607548617e-14, -1.9668431344970835e-14)
# tuniv = 172.53 xuniv = 79.84%  Checking the solution:  -4.3298697960381105e-15
# Fold-change in tumor size: 2.30
# * Parameters: T = 4.0, Tbar = 18.0 (μ = 0.25000, μbar = 0.05556)
# Ending point: t = 5.99, x = 92.67%  Checking the solution: (-3.2794053693582185e-14, 2.5586402431522086e-14)
# tuniv = 172.64 xuniv = 79.24%  Checking the solution:  -2.147761135606885e-14
# Fold-change in tumor size: 2.26
# * Parameters: T = 4.0, Tbar = 17.0 (μ = 0.25000, μbar = 0.05882)
# Ending point: t = 5.94, x = 92.32%  Checking the solution: (-2.467021497317024e-08, -1.2512861314205442e-07)
# tuniv = 172.79 xuniv = 78.52%  Checking the solution:  4.702835343373124e-15
# Fold-change in tumor size: 2.21
# * Parameters: T = 4.0, Tbar = 16.0 (μ = 0.25000, μbar = 0.06250)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 5.88, x = 91.94%  Checking the solution: (2.7030889949572685e-13, 1.4402753816164224e-13)
# tuniv = 172.89 xuniv = 77.91%  Checking the solution:  2.089474426814064e-15
# Fold-change in tumor size: 2.15
# * Parameters: T = 4.0, Tbar = 15.0 (μ = 0.25000, μbar = 0.06667)
# Ending point: t = 5.81, x = 91.52%  Checking the solution: (-2.6317233146791347e-08, -3.618303066266207e-10)
# tuniv = 173.02 xuniv = 77.17%  Checking the solution:  1.5955986532034672e-14
# Fold-change in tumor size: 2.09
# * Parameters: T = 4.0, Tbar = 14.0 (μ = 0.25000, μbar = 0.07143)
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 5.74, x = 91.04%  Checking the solution: (-4.216160573574092e-09, -1.0433866822383616e-09)
# tuniv = 173.16 xuniv = 76.36%  Checking the solution:  1.779826286352204e-14
# Fold-change in tumor size: 2.03
# * Parameters: T = 4.0, Tbar = 13.0 (μ = 0.25000, μbar = 0.07692)
# ! Trying again... Convergence is not sufficient
# Ending point: t = 5.67, x = 90.51%  Checking the solution: (-2.496109117909259e-12, -2.0437049208461436e-12)
# tuniv = 173.31 xuniv = 75.48%  Checking the solution:  -4.6455894686658894e-15
# Fold-change in tumor size: 1.96
# * Parameters: T = 4.0, Tbar = 12.0 (μ = 0.25000, μbar = 0.08333)
# Ending point: t = 5.58, x = 89.91%  Checking the solution: (3.5394740293097636e-12, 1.8619304464298386e-12)
# tuniv = 173.46 xuniv = 74.52%  Checking the solution:  -4.371503159461554e-15
# Fold-change in tumor size: 1.89
# * Parameters: T = 4.0, Tbar = 11.0 (μ = 0.25000, μbar = 0.09091)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Ending point: t = 5.49, x = 89.21%  Checking the solution: (-5.660981046607811e-08, -3.5125855458638877e-08)
# tuniv = 173.62 xuniv = 73.44%  Checking the solution:  -1.3027773304585821e-14
# Fold-change in tumor size: 1.80
# * Parameters: T = 4.0, Tbar = 10.0 (μ = 0.25000, μbar = 0.10000)
# Ending point: t = 5.40, x = 88.41%  Checking the solution: (-2.8388127052926555e-07, -2.4340931695362653e-08)
# tuniv = 173.79 xuniv = 72.26%  Checking the solution:  1.8041124150158794e-15
# Fold-change in tumor size: 1.71
# * Parameters: T = 4.0, Tbar = 9.0 (μ = 0.25000, μbar = 0.11111)
# Ending point: t = 5.29, x = 87.48%  Checking the solution: (-2.2520723497072476e-07, -5.981053906438133e-07)
# tuniv = 174.06 xuniv = 70.66%  Checking the solution:  -2.884636973732313e-13
# Fold-change in tumor size: 1.61
# * Parameters: T = 4.0, Tbar = 8.0 (μ = 0.25000, μbar = 0.12500)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# Ending point: t = 5.17, x = 86.36%  Checking the solution: (-9.110660108305368e-08, -4.1231732825335393e-07)
# tuniv = 174.22 xuniv = 69.26%  Checking the solution:  -6.369904603786836e-14
# Fold-change in tumor size: 1.50
# * Parameters: T = 4.0, Tbar = 7.0 (μ = 0.25000, μbar = 0.14286)
# Ending point: t = 5.03, x = 85.01%  Checking the solution: (-1.9437239231377675e-07, -5.600299308817965e-07)
# tuniv = 174.45 xuniv = 67.47%  Checking the solution:  -1.508099201075197e-13
# Fold-change in tumor size: 1.37
# * Parameters: T = 4.0, Tbar = 6.0 (μ = 0.25000, μbar = 0.16667)
# Ending point: t = 4.87, x = 83.33%  Checking the solution: (-1.1450984107071872e-07, 2.7609705689502086e-07)
# tuniv = 174.59 xuniv = 65.81%  Checking the solution:  -5.3028761937135016e-14
# Fold-change in tumor size: 1.23
# * Parameters: T = 4.0, Tbar = 5.0 (μ = 0.25000, μbar = 0.20000)
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# ! Trying again... Convergence is not sufficient
# ! Trying again... The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Ending point: t = 4.69, x = 81.17%  Checking the solution: (-6.118556723765563e-08, 1.5882021153390923e-07)
# tuniv = 174.86 xuniv = 63.33%  Checking the solution:  -7.791295386638808e-12
# Fold-change in tumor size: 1.06
# * Parameters: T = 4.0, Tbar = 4.0 (μ = 0.25000, μbar = 0.25000)
# Ending point: t = 4.48, x = 78.28%  Checking the solution: (9.975906446670502e-13, 6.83565417666343e-13)
# tuniv = 175.17 xuniv = 60.26%  Checking the solution:  -1.3161873674283342e-10
# Fold-change in tumor size: 0.88
